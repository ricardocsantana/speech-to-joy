# %%
import torch
import torchaudio
from transformers import HubertModel
import numpy as np
import os
import pandas as pd

df_user =  pd.read_excel("user-self-reports/target-enjoyment.xlsx", sheet_name='target-enjoyment', header=1)

def extract_hubert_embeddings(audio_file_path, model_name="facebook/hubert-xlarge-ll60k", output_dir="audio-embeddings"):
    """
    Extracts Hubert embeddings from a .wav audio file.

    Args:
        audio_file_path (str): Path to the .wav audio file.
        model_name (str, optional): Name of the pretrained Hubert model.
            Defaults to "facebook/hubert-base-ls960". You can also use
            "hubert-large-ls960-ft".
        output_dir (str, optional): Directory to save the embeddings.
            Defaults to "embeddings".
    Returns:
        numpy.ndarray: The Hubert embeddings, or None if an error occurs.
    """
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Created output directory: {output_dir}")

    # Load the Hubert model
    try:
        print(f"Loading Hubert model: {model_name}...")
        model = HubertModel.from_pretrained(model_name)
        print("Model loaded successfully.")
    except Exception as e:
        print(f"Error: Failed to load Hubert model {model_name}. Check the model name and your network connection.")
        print(f"Exception: {e}")
        return None

    # Set the model to evaluation mode
    model.eval()

    # Load the audio file using torchaudio
    try:
        print(f"Loading audio file: {audio_file_path}...")
        waveform, sample_rate = torchaudio.load(audio_file_path)
        print(f"Audio loaded. Initial shape: {waveform.shape}, Sample rate: {sample_rate}")
    except Exception as e:
        print(f"Error: Failed to load audio file {audio_file_path}. Ensure it is a valid .wav file.")
        print(f"Exception: {e}")
        return None

    # Resample the audio if necessary. Hubert models are often trained on 16000 Hz audio.
    target_sample_rate = 16000
    if sample_rate != target_sample_rate:
        print(f"Resampling audio from {sample_rate} Hz to {target_sample_rate} Hz...")
        resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=target_sample_rate)
        waveform = resampler(waveform)
        print(f"Resampled audio shape: {waveform.shape}")

    # Ensure the waveform is mono (Hubert expects mono audio)
    if waveform.shape[0] > 1:
        print("Converting audio to mono...")
        waveform = torch.mean(waveform, dim=0, keepdim=True)
        print(f"Mono audio shape: {waveform.shape}")

    # --- FIX: Prepare waveform for the model ---
    # The model expects input shape (batch_size, sequence_length).
    # Current shape is likely [1, sequence_length] (mono audio).
    # We need to remove the channel dimension first, then add the batch dimension.

    # Remove the channel dimension (dim=0) if it exists
    if waveform.dim() > 1 and waveform.shape[0] == 1:
         waveform = waveform.squeeze(0) # Shape becomes [sequence_length]
         print(f"Squeezed waveform shape: {waveform.shape}")


    # Add a batch dimension (batch size of 1) at the beginning
    waveform = waveform.unsqueeze(0) # Shape becomes [1, sequence_length]
    print(f"Final waveform shape for model: {waveform.shape}")
    # --- End of FIX ---


    # Disable gradient calculations to save memory and increase speed
    with torch.no_grad():
        try:
            print("Extracting embeddings...")
            # Get the Hubert embeddings. The output is a dictionary.
            # The 'last_hidden_state' key contains the embeddings.
            output = model(waveform)
            embeddings = output.last_hidden_state
            print("Embeddings extracted successfully.")
        except Exception as e:
            print(f"Error: Failed to process audio with Hubert model.")
            print(f"Input tensor shape at error: {waveform.shape}") # Print shape right before error
            print(f"Exception: {e}")
            return None

    # Convert the embeddings to a numpy array
    # Output shape is (batch_size, sequence_length_out, hidden_size)
    embeddings_numpy = embeddings.squeeze(0).cpu().numpy()  # Remove batch dimension
    print(f"Embeddings numpy shape: {embeddings_numpy.shape}")

    # Save the embeddings to a .npy file
    audio_file_name = os.path.splitext(os.path.basename(audio_file_path))[0]
    output_file_path = os.path.join(output_dir, f"{audio_file_name}_hubert_embeddings.npy")
    try:
        np.save(output_file_path, embeddings_numpy)
        print(f"Saved embeddings to {output_file_path}")
    except Exception as e:
        print(f"Error: Failed to save embeddings to {output_file_path}")
        print(f"Exception: {e}")
        return None # Return None if saving fails

    return embeddings_numpy

if __name__ == "__main__":

    for person in range(4, 43):
        if person == 26:
            continue
        robot_first_interaction = df_user.loc[df_user["PID"] == person, "Q1-Robot"].values[0]
        embeddings = []    
        turn = []
        df = pd.read_excel(f"data/text/P{person}/text-aligned-P{person}.xlsx", header=0)
        for i, row in df.iterrows():
            audio = f"data/audio_vad_300/P{person}/trimmed_audio-P{person}-{robot_first_interaction}-{i+1}.wav"
            # Check if the audio file exists
            if not os.path.exists(audio):
                print(f"Audio file {audio} does not exist. Skipping.")
                continue
            # Check audio duration in seconds from .wav file
            audio_info = torchaudio.info(audio)
            duration = audio_info.num_frames / audio_info.sample_rate

            turn.append(i+1)

            embedding = extract_hubert_embeddings(audio)
            if embedding is not None:
                embeddings.append(np.mean(embedding, axis=0))  # Average the embeddings across time
            else:
                print(f"Failed to extract embedding for {audio}")
        # Save all embeddings for the personxrobot
        os.makedirs(f"data/audio-datasets/hubert-xlarge-ll60k", exist_ok=True)
        df_out = pd.DataFrame()
        df_out["Utterance ID"] = turn
        df_out = pd.concat([df_out, pd.DataFrame(embeddings)], axis=1)
        # Save the DataFrame to a CSV file
        df_out.to_csv(f"data/audio-datasets/hubert-xlarge-ll60k/audio-dataset{robot_first_interaction}-P{person}.csv", index=False)
        print(f"Saved embeddings for {robot_first_interaction} P{person} to CSV.")
# Out:
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-1.wav...
# Audio loaded. Initial shape: torch.Size([1, 53760]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 26880])
# Squeezed waveform shape: torch.Size([26880])
# Final waveform shape for model: torch.Size([1, 26880])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (83, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-1_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-2.wav...
# Audio loaded. Initial shape: torch.Size([1, 51840]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 25920])
# Squeezed waveform shape: torch.Size([25920])
# Final waveform shape for model: torch.Size([1, 25920])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (80, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-2_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-3.wav...
# Audio loaded. Initial shape: torch.Size([1, 112032]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 56016])
# Squeezed waveform shape: torch.Size([56016])
# Final waveform shape for model: torch.Size([1, 56016])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (174, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-3_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-4.wav...
# Audio loaded. Initial shape: torch.Size([1, 104032]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 52016])
# Squeezed waveform shape: torch.Size([52016])
# Final waveform shape for model: torch.Size([1, 52016])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (162, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-4_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-5.wav...
# Audio loaded. Initial shape: torch.Size([1, 21120]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 10560])
# Squeezed waveform shape: torch.Size([10560])
# Final waveform shape for model: torch.Size([1, 10560])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (32, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-5_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-6.wav...
# Audio loaded. Initial shape: torch.Size([1, 427200]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 213600])
# Squeezed waveform shape: torch.Size([213600])
# Final waveform shape for model: torch.Size([1, 213600])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (667, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-6_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-7.wav...
# Audio loaded. Initial shape: torch.Size([1, 42240]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 21120])
# Squeezed waveform shape: torch.Size([21120])
# Final waveform shape for model: torch.Size([1, 21120])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (65, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-7_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-8.wav...
# Audio loaded. Initial shape: torch.Size([1, 110400]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 55200])
# Squeezed waveform shape: torch.Size([55200])
# Final waveform shape for model: torch.Size([1, 55200])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (172, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-8_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-9.wav...
# Audio loaded. Initial shape: torch.Size([1, 482976]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 241488])
# Squeezed waveform shape: torch.Size([241488])
# Final waveform shape for model: torch.Size([1, 241488])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (754, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-9_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-10.wav...
# Audio loaded. Initial shape: torch.Size([1, 37440]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 18720])
# Squeezed waveform shape: torch.Size([18720])
# Final waveform shape for model: torch.Size([1, 18720])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (58, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-10_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-11.wav...
# Audio loaded. Initial shape: torch.Size([1, 146176]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 73088])
# Squeezed waveform shape: torch.Size([73088])
# Final waveform shape for model: torch.Size([1, 73088])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (228, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-11_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-12.wav...
# Audio loaded. Initial shape: torch.Size([1, 50880]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 25440])
# Squeezed waveform shape: torch.Size([25440])
# Final waveform shape for model: torch.Size([1, 25440])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (79, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-12_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-13.wav...
# Audio loaded. Initial shape: torch.Size([1, 54720]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 27360])
# Squeezed waveform shape: torch.Size([27360])
# Final waveform shape for model: torch.Size([1, 27360])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (85, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-13_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-14.wav...
# Audio loaded. Initial shape: torch.Size([1, 129280]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 64640])
# Squeezed waveform shape: torch.Size([64640])
# Final waveform shape for model: torch.Size([1, 64640])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (201, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-14_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-15.wav...
# Audio loaded. Initial shape: torch.Size([1, 100800]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 50400])
# Squeezed waveform shape: torch.Size([50400])
# Final waveform shape for model: torch.Size([1, 50400])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (157, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-15_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-16.wav...
# Audio loaded. Initial shape: torch.Size([1, 325312]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 162656])
# Squeezed waveform shape: torch.Size([162656])
# Final waveform shape for model: torch.Size([1, 162656])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (508, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-16_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-17.wav...
# Audio loaded. Initial shape: torch.Size([1, 55680]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 27840])
# Squeezed waveform shape: torch.Size([27840])
# Final waveform shape for model: torch.Size([1, 27840])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (86, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-17_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-18.wav...
# Audio loaded. Initial shape: torch.Size([1, 258912]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 129456])
# Squeezed waveform shape: torch.Size([129456])
# Final waveform shape for model: torch.Size([1, 129456])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (404, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-18_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-19.wav...
# Audio loaded. Initial shape: torch.Size([1, 333120]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 166560])
# Squeezed waveform shape: torch.Size([166560])
# Final waveform shape for model: torch.Size([1, 166560])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (520, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-19_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-20.wav...
# Audio loaded. Initial shape: torch.Size([1, 164160]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 82080])
# Squeezed waveform shape: torch.Size([82080])
# Final waveform shape for model: torch.Size([1, 82080])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (256, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-20_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-21.wav...
# Audio loaded. Initial shape: torch.Size([1, 71040]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 35520])
# Squeezed waveform shape: torch.Size([35520])
# Final waveform shape for model: torch.Size([1, 35520])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (110, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-21_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-22.wav...
# Audio loaded. Initial shape: torch.Size([1, 209280]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 104640])
# Squeezed waveform shape: torch.Size([104640])
# Final waveform shape for model: torch.Size([1, 104640])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (326, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-22_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-23.wav...
# Audio loaded. Initial shape: torch.Size([1, 82464]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 41232])
# Squeezed waveform shape: torch.Size([41232])
# Final waveform shape for model: torch.Size([1, 41232])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (128, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-23_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-24.wav...
# Audio loaded. Initial shape: torch.Size([1, 119680]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 59840])
# Squeezed waveform shape: torch.Size([59840])
# Final waveform shape for model: torch.Size([1, 59840])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (186, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-24_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-25.wav...
# Audio loaded. Initial shape: torch.Size([1, 299520]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 149760])
# Squeezed waveform shape: torch.Size([149760])
# Final waveform shape for model: torch.Size([1, 149760])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (467, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-25_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-26.wav...
# Audio loaded. Initial shape: torch.Size([1, 629344]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 314672])
# Squeezed waveform shape: torch.Size([314672])
# Final waveform shape for model: torch.Size([1, 314672])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (983, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-26_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P4/trimmed_audio-P4-Alice-27.wav...
# Audio loaded. Initial shape: torch.Size([1, 129440]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 64720])
# Squeezed waveform shape: torch.Size([64720])
# Final waveform shape for model: torch.Size([1, 64720])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (202, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-27_hubert_embeddings.npy
# Audio file data/audio_vad_300/P4/trimmed_audio-P4-Alice-28.wav does not exist. Skipping.
# Saved embeddings for Alice P4 to CSV.
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-1.wav...
# Audio loaded. Initial shape: torch.Size([1, 34912]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 17456])
# Squeezed waveform shape: torch.Size([17456])
# Final waveform shape for model: torch.Size([1, 17456])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (54, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-1_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-2.wav...
# Audio loaded. Initial shape: torch.Size([1, 109984]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 54992])
# Squeezed waveform shape: torch.Size([54992])
# Final waveform shape for model: torch.Size([1, 54992])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (171, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-2_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-3.wav...
# Audio loaded. Initial shape: torch.Size([1, 118880]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 59440])
# Squeezed waveform shape: torch.Size([59440])
# Final waveform shape for model: torch.Size([1, 59440])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (185, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-3_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-4.wav...
# Audio loaded. Initial shape: torch.Size([1, 239872]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 119936])
# Squeezed waveform shape: torch.Size([119936])
# Final waveform shape for model: torch.Size([1, 119936])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (374, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-4_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-5.wav...
# Audio loaded. Initial shape: torch.Size([1, 193920]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 96960])
# Squeezed waveform shape: torch.Size([96960])
# Final waveform shape for model: torch.Size([1, 96960])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (302, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-5_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-6.wav...
# Audio loaded. Initial shape: torch.Size([1, 384096]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 192048])
# Squeezed waveform shape: torch.Size([192048])
# Final waveform shape for model: torch.Size([1, 192048])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (599, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-6_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-7.wav...
# Audio loaded. Initial shape: torch.Size([1, 369600]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 184800])
# Squeezed waveform shape: torch.Size([184800])
# Final waveform shape for model: torch.Size([1, 184800])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (577, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-7_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-8.wav...
# Audio loaded. Initial shape: torch.Size([1, 434688]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 217344])
# Squeezed waveform shape: torch.Size([217344])
# Final waveform shape for model: torch.Size([1, 217344])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (678, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-8_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-9.wav...
# Audio loaded. Initial shape: torch.Size([1, 276480]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 138240])
# Squeezed waveform shape: torch.Size([138240])
# Final waveform shape for model: torch.Size([1, 138240])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (431, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-9_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-10.wav...
# Audio loaded. Initial shape: torch.Size([1, 823904]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 411952])
# Squeezed waveform shape: torch.Size([411952])
# Final waveform shape for model: torch.Size([1, 411952])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1287, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-10_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-11.wav...
# Audio loaded. Initial shape: torch.Size([1, 18656]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 9328])
# Squeezed waveform shape: torch.Size([9328])
# Final waveform shape for model: torch.Size([1, 9328])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (28, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-11_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-12.wav...
# Audio loaded. Initial shape: torch.Size([1, 378240]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 189120])
# Squeezed waveform shape: torch.Size([189120])
# Final waveform shape for model: torch.Size([1, 189120])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (590, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-12_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-13.wav...
# Audio loaded. Initial shape: torch.Size([1, 934144]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 467072])
# Squeezed waveform shape: torch.Size([467072])
# Final waveform shape for model: torch.Size([1, 467072])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1459, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-13_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-14.wav...
# Audio loaded. Initial shape: torch.Size([1, 51264]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 25632])
# Squeezed waveform shape: torch.Size([25632])
# Final waveform shape for model: torch.Size([1, 25632])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (79, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-14_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-15.wav...
# Audio loaded. Initial shape: torch.Size([1, 86944]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 43472])
# Squeezed waveform shape: torch.Size([43472])
# Final waveform shape for model: torch.Size([1, 43472])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (135, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-15_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-16.wav...
# Audio loaded. Initial shape: torch.Size([1, 140128]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 70064])
# Squeezed waveform shape: torch.Size([70064])
# Final waveform shape for model: torch.Size([1, 70064])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (218, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-16_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-17.wav...
# Audio loaded. Initial shape: torch.Size([1, 93120]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 46560])
# Squeezed waveform shape: torch.Size([46560])
# Final waveform shape for model: torch.Size([1, 46560])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (145, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-17_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-18.wav...
# Audio loaded. Initial shape: torch.Size([1, 189472]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 94736])
# Squeezed waveform shape: torch.Size([94736])
# Final waveform shape for model: torch.Size([1, 94736])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (295, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-18_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-19.wav...
# Audio loaded. Initial shape: torch.Size([1, 195168]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 97584])
# Squeezed waveform shape: torch.Size([97584])
# Final waveform shape for model: torch.Size([1, 97584])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (304, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-19_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-20.wav...
# Audio loaded. Initial shape: torch.Size([1, 789472]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 394736])
# Squeezed waveform shape: torch.Size([394736])
# Final waveform shape for model: torch.Size([1, 394736])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1233, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-20_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P5/trimmed_audio-P5-Clara-21.wav...
# Audio loaded. Initial shape: torch.Size([1, 18560]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 9280])
# Squeezed waveform shape: torch.Size([9280])
# Final waveform shape for model: torch.Size([1, 9280])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (28, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-21_hubert_embeddings.npy
# Saved embeddings for Clara P5 to CSV.
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-1.wav...
# Audio loaded. Initial shape: torch.Size([1, 29728]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 14864])
# Squeezed waveform shape: torch.Size([14864])
# Final waveform shape for model: torch.Size([1, 14864])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (46, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-1_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-2.wav...
# Audio loaded. Initial shape: torch.Size([1, 110400]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 55200])
# Squeezed waveform shape: torch.Size([55200])
# Final waveform shape for model: torch.Size([1, 55200])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (172, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-2_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-3.wav...
# Audio loaded. Initial shape: torch.Size([1, 268992]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 134496])
# Squeezed waveform shape: torch.Size([134496])
# Final waveform shape for model: torch.Size([1, 134496])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (420, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-3_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-4.wav...
# Audio loaded. Initial shape: torch.Size([1, 549856]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 274928])
# Squeezed waveform shape: torch.Size([274928])
# Final waveform shape for model: torch.Size([1, 274928])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (858, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-4_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-5.wav...
# Audio loaded. Initial shape: torch.Size([1, 520096]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 260048])
# Squeezed waveform shape: torch.Size([260048])
# Final waveform shape for model: torch.Size([1, 260048])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (812, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-5_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-6.wav...
# Audio loaded. Initial shape: torch.Size([1, 330496]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 165248])
# Squeezed waveform shape: torch.Size([165248])
# Final waveform shape for model: torch.Size([1, 165248])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (516, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-6_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-7.wav...
# Audio loaded. Initial shape: torch.Size([1, 1341888]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 670944])
# Squeezed waveform shape: torch.Size([670944])
# Final waveform shape for model: torch.Size([1, 670944])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (2096, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-7_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-8.wav...
# Audio loaded. Initial shape: torch.Size([1, 959808]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 479904])
# Squeezed waveform shape: torch.Size([479904])
# Final waveform shape for model: torch.Size([1, 479904])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1499, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-8_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-9.wav...
# Audio loaded. Initial shape: torch.Size([1, 909472]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 454736])
# Squeezed waveform shape: torch.Size([454736])
# Final waveform shape for model: torch.Size([1, 454736])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1420, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-9_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-10.wav...
# Audio loaded. Initial shape: torch.Size([1, 750464]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 375232])
# Squeezed waveform shape: torch.Size([375232])
# Final waveform shape for model: torch.Size([1, 375232])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1172, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-10_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-11.wav...
# Audio loaded. Initial shape: torch.Size([1, 36480]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 18240])
# Squeezed waveform shape: torch.Size([18240])
# Final waveform shape for model: torch.Size([1, 18240])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (56, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-11_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-12.wav...
# Audio loaded. Initial shape: torch.Size([1, 186112]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 93056])
# Squeezed waveform shape: torch.Size([93056])
# Final waveform shape for model: torch.Size([1, 93056])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (290, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-12_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-13.wav...
# Audio loaded. Initial shape: torch.Size([1, 995680]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 497840])
# Squeezed waveform shape: torch.Size([497840])
# Final waveform shape for model: torch.Size([1, 497840])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1555, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-13_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P6/trimmed_audio-P6-Clara-14.wav...
# Audio loaded. Initial shape: torch.Size([1, 59392]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 29696])
# Squeezed waveform shape: torch.Size([29696])
# Final waveform shape for model: torch.Size([1, 29696])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (92, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-14_hubert_embeddings.npy
# Audio file data/audio_vad_300/P6/trimmed_audio-P6-Clara-15.wav does not exist. Skipping.
# Saved embeddings for Clara P6 to CSV.
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-1.wav...
# Audio loaded. Initial shape: torch.Size([1, 131936]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 65968])
# Squeezed waveform shape: torch.Size([65968])
# Final waveform shape for model: torch.Size([1, 65968])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (205, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-1_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-2.wav...
# Audio loaded. Initial shape: torch.Size([1, 247680]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 123840])
# Squeezed waveform shape: torch.Size([123840])
# Final waveform shape for model: torch.Size([1, 123840])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (386, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-2_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-3.wav...
# Audio loaded. Initial shape: torch.Size([1, 522240]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 261120])
# Squeezed waveform shape: torch.Size([261120])
# Final waveform shape for model: torch.Size([1, 261120])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (815, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-3_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-4.wav...
# Audio loaded. Initial shape: torch.Size([1, 143552]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 71776])
# Squeezed waveform shape: torch.Size([71776])
# Final waveform shape for model: torch.Size([1, 71776])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (224, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-4_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-5.wav...
# Audio loaded. Initial shape: torch.Size([1, 467616]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 233808])
# Squeezed waveform shape: torch.Size([233808])
# Final waveform shape for model: torch.Size([1, 233808])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (730, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-5_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-6.wav...
# Audio loaded. Initial shape: torch.Size([1, 96000]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 48000])
# Squeezed waveform shape: torch.Size([48000])
# Final waveform shape for model: torch.Size([1, 48000])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (149, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-6_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-7.wav...
# Audio loaded. Initial shape: torch.Size([1, 726624]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 363312])
# Squeezed waveform shape: torch.Size([363312])
# Final waveform shape for model: torch.Size([1, 363312])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1135, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-7_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-8.wav...
# Audio loaded. Initial shape: torch.Size([1, 188288]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 94144])
# Squeezed waveform shape: torch.Size([94144])
# Final waveform shape for model: torch.Size([1, 94144])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (293, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-8_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-9.wav...
# Audio loaded. Initial shape: torch.Size([1, 135680]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 67840])
# Squeezed waveform shape: torch.Size([67840])
# Final waveform shape for model: torch.Size([1, 67840])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (211, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-9_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-10.wav...
# Audio loaded. Initial shape: torch.Size([1, 157152]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 78576])
# Squeezed waveform shape: torch.Size([78576])
# Final waveform shape for model: torch.Size([1, 78576])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (245, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-10_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-11.wav...
# Audio loaded. Initial shape: torch.Size([1, 710944]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 355472])
# Squeezed waveform shape: torch.Size([355472])
# Final waveform shape for model: torch.Size([1, 355472])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1110, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-11_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-12.wav...
# Audio loaded. Initial shape: torch.Size([1, 507872]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 253936])
# Squeezed waveform shape: torch.Size([253936])
# Final waveform shape for model: torch.Size([1, 253936])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (793, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-12_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-13.wav...
# Audio loaded. Initial shape: torch.Size([1, 515520]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 257760])
# Squeezed waveform shape: torch.Size([257760])
# Final waveform shape for model: torch.Size([1, 257760])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (805, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-13_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-14.wav...
# Audio loaded. Initial shape: torch.Size([1, 356864]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 178432])
# Squeezed waveform shape: torch.Size([178432])
# Final waveform shape for model: torch.Size([1, 178432])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (557, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-14_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-15.wav...
# Audio loaded. Initial shape: torch.Size([1, 731968]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 365984])
# Squeezed waveform shape: torch.Size([365984])
# Final waveform shape for model: torch.Size([1, 365984])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1143, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-15_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-16.wav...
# Audio loaded. Initial shape: torch.Size([1, 86400]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 43200])
# Squeezed waveform shape: torch.Size([43200])
# Final waveform shape for model: torch.Size([1, 43200])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (134, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-16_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P7/trimmed_audio-P7-Clara-17.wav...
# Audio loaded. Initial shape: torch.Size([1, 714624]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 357312])
# Squeezed waveform shape: torch.Size([357312])
# Final waveform shape for model: torch.Size([1, 357312])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1116, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-17_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# ...
# Embeddings numpy shape: (368, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-3_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-4.wav...
# Audio loaded. Initial shape: torch.Size([1, 191040]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 95520])
# Squeezed waveform shape: torch.Size([95520])
# Final waveform shape for model: torch.Size([1, 95520])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (298, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-4_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-5.wav...
# Audio loaded. Initial shape: torch.Size([1, 202560]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 101280])
# Squeezed waveform shape: torch.Size([101280])
# Final waveform shape for model: torch.Size([1, 101280])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (316, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-5_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-6.wav...
# Audio loaded. Initial shape: torch.Size([1, 364096]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 182048])
# Squeezed waveform shape: torch.Size([182048])
# Final waveform shape for model: torch.Size([1, 182048])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (568, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-6_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-7.wav...
# Audio loaded. Initial shape: torch.Size([1, 193248]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 96624])
# Squeezed waveform shape: torch.Size([96624])
# Final waveform shape for model: torch.Size([1, 96624])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (301, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-7_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-8.wav...
# Audio loaded. Initial shape: torch.Size([1, 212160]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 106080])
# Squeezed waveform shape: torch.Size([106080])
# Final waveform shape for model: torch.Size([1, 106080])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (331, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-8_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-9.wav...
# Audio loaded. Initial shape: torch.Size([1, 229216]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 114608])
# Squeezed waveform shape: torch.Size([114608])
# Final waveform shape for model: torch.Size([1, 114608])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (357, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-9_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-10.wav...
# Audio loaded. Initial shape: torch.Size([1, 195424]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 97712])
# Squeezed waveform shape: torch.Size([97712])
# Final waveform shape for model: torch.Size([1, 97712])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (305, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-10_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-11.wav...
# Audio loaded. Initial shape: torch.Size([1, 93120]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 46560])
# Squeezed waveform shape: torch.Size([46560])
# Final waveform shape for model: torch.Size([1, 46560])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (145, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-11_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-12.wav...
# Audio loaded. Initial shape: torch.Size([1, 171840]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 85920])
# Squeezed waveform shape: torch.Size([85920])
# Final waveform shape for model: torch.Size([1, 85920])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (268, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-12_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-13.wav...
# Audio loaded. Initial shape: torch.Size([1, 179520]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 89760])
# Squeezed waveform shape: torch.Size([89760])
# Final waveform shape for model: torch.Size([1, 89760])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (280, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-13_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-14.wav...
# Audio loaded. Initial shape: torch.Size([1, 240736]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 120368])
# Squeezed waveform shape: torch.Size([120368])
# Final waveform shape for model: torch.Size([1, 120368])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (375, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-14_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-15.wav...
# Audio loaded. Initial shape: torch.Size([1, 384960]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 192480])
# Squeezed waveform shape: torch.Size([192480])
# Final waveform shape for model: torch.Size([1, 192480])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (601, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-15_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-16.wav...
# Audio loaded. Initial shape: torch.Size([1, 319680]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 159840])
# Squeezed waveform shape: torch.Size([159840])
# Final waveform shape for model: torch.Size([1, 159840])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (499, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-16_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-17.wav...
# Audio loaded. Initial shape: torch.Size([1, 196800]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 98400])
# Squeezed waveform shape: torch.Size([98400])
# Final waveform shape for model: torch.Size([1, 98400])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (307, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-17_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-18.wav...
# Audio loaded. Initial shape: torch.Size([1, 127360]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 63680])
# Squeezed waveform shape: torch.Size([63680])
# Final waveform shape for model: torch.Size([1, 63680])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (198, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-18_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-19.wav...
# Audio loaded. Initial shape: torch.Size([1, 500160]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 250080])
# Squeezed waveform shape: torch.Size([250080])
# Final waveform shape for model: torch.Size([1, 250080])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (781, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-19_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-20.wav...
# Audio loaded. Initial shape: torch.Size([1, 393504]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 196752])
# Squeezed waveform shape: torch.Size([196752])
# Final waveform shape for model: torch.Size([1, 196752])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (614, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-20_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-21.wav...
# Audio loaded. Initial shape: torch.Size([1, 276480]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 138240])
# Squeezed waveform shape: torch.Size([138240])
# Final waveform shape for model: torch.Size([1, 138240])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (431, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-21_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-22.wav...
# Audio loaded. Initial shape: torch.Size([1, 126368]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 63184])
# Squeezed waveform shape: torch.Size([63184])
# Final waveform shape for model: torch.Size([1, 63184])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (197, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-22_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-23.wav...
# Audio loaded. Initial shape: torch.Size([1, 80640]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 40320])
# Squeezed waveform shape: torch.Size([40320])
# Final waveform shape for model: torch.Size([1, 40320])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (125, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-23_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-24.wav...
# Audio loaded. Initial shape: torch.Size([1, 120000]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 60000])
# Squeezed waveform shape: torch.Size([60000])
# Final waveform shape for model: torch.Size([1, 60000])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (187, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-24_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-25.wav...
# Audio loaded. Initial shape: torch.Size([1, 46816]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 23408])
# Squeezed waveform shape: torch.Size([23408])
# Final waveform shape for model: torch.Size([1, 23408])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (72, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-25_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-26.wav...
# Audio loaded. Initial shape: torch.Size([1, 58560]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 29280])
# Squeezed waveform shape: torch.Size([29280])
# Final waveform shape for model: torch.Size([1, 29280])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (91, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-26_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-27.wav...
# Audio loaded. Initial shape: torch.Size([1, 271200]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 135600])
# Squeezed waveform shape: torch.Size([135600])
# Final waveform shape for model: torch.Size([1, 135600])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (423, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-27_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-28.wav...
# Audio loaded. Initial shape: torch.Size([1, 224224]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 112112])
# Squeezed waveform shape: torch.Size([112112])
# Final waveform shape for model: torch.Size([1, 112112])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (350, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-28_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-xlarge-ll60k...
# Model loaded successfully.
# Loading audio file: data/audio_vad_300/P42/trimmed_audio-P42-Alice-29.wav...
# Audio loaded. Initial shape: torch.Size([1, 164160]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 82080])
# Squeezed waveform shape: torch.Size([82080])
# Final waveform shape for model: torch.Size([1, 82080])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (256, 1280)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-29_hubert_embeddings.npy
# Audio file data/audio_vad_300/P42/trimmed_audio-P42-Alice-30.wav does not exist. Skipping.
# Saved embeddings for Alice P42 to CSV.
