# %%
import torch
import torchaudio
from transformers import HubertModel
import numpy as np
import os
import pandas as pd

df_user =  pd.read_excel("user-self-reports/target-enjoyment.xlsx", sheet_name='target-enjoyment', header=1)

def extract_hubert_embeddings(audio_file_path, model_name="facebook/hubert-large-ls960-ft", output_dir="audio-embeddings"):
    """
    Extracts Hubert embeddings from a .wav audio file.

    Args:
        audio_file_path (str): Path to the .wav audio file.
        model_name (str, optional): Name of the pretrained Hubert model.
            Defaults to "facebook/hubert-base-ls960". You can also use
            "hubert-large-ls960-ft".
        output_dir (str, optional): Directory to save the embeddings.
            Defaults to "embeddings".
    Returns:
        numpy.ndarray: The Hubert embeddings, or None if an error occurs.
    """
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Created output directory: {output_dir}")

    # Load the Hubert model
    try:
        print(f"Loading Hubert model: {model_name}...")
        model = HubertModel.from_pretrained(model_name)
        print("Model loaded successfully.")
    except Exception as e:
        print(f"Error: Failed to load Hubert model {model_name}. Check the model name and your network connection.")
        print(f"Exception: {e}")
        return None

    """    # Move the model to GPU if available
    if torch.backends.mps.is_available():
        print("Using Apple Silicon GPU (MPS) for inference.")
    else:
        print("Using CPU for inference.")
    model.to(torch.device("cpu"))  # Move model to GPU if available"""
    # Set the model to evaluation mode
    model.eval()

    # Load the audio file using torchaudio
    try:
        print(f"Loading audio file: {audio_file_path}...")
        waveform, sample_rate = torchaudio.load(audio_file_path)
        print(f"Audio loaded. Initial shape: {waveform.shape}, Sample rate: {sample_rate}")
    except Exception as e:
        print(f"Error: Failed to load audio file {audio_file_path}. Ensure it is a valid .wav file.")
        print(f"Exception: {e}")
        return None

    # Resample the audio if necessary. Hubert models are often trained on 16000 Hz audio.
    target_sample_rate = 16000
    if sample_rate != target_sample_rate:
        print(f"Resampling audio from {sample_rate} Hz to {target_sample_rate} Hz...")
        resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=target_sample_rate)
        waveform = resampler(waveform)
        print(f"Resampled audio shape: {waveform.shape}")

    # Ensure the waveform is mono (Hubert expects mono audio)
    if waveform.shape[0] > 1:
        print("Converting audio to mono...")
        waveform = torch.mean(waveform, dim=0, keepdim=True)
        print(f"Mono audio shape: {waveform.shape}")

    # --- FIX: Prepare waveform for the model ---
    # The model expects input shape (batch_size, sequence_length).
    # Current shape is likely [1, sequence_length] (mono audio).
    # We need to remove the channel dimension first, then add the batch dimension.

    # Remove the channel dimension (dim=0) if it exists
    if waveform.dim() > 1 and waveform.shape[0] == 1:
         waveform = waveform.squeeze(0) # Shape becomes [sequence_length]
         print(f"Squeezed waveform shape: {waveform.shape}")


    # Add a batch dimension (batch size of 1) at the beginning
    waveform = waveform.unsqueeze(0) # Shape becomes [1, sequence_length]
    print(f"Final waveform shape for model: {waveform.shape}")
    # --- End of FIX ---


    # Disable gradient calculations to save memory and increase speed
    with torch.no_grad():
        try:
            print("Extracting embeddings...")
            # Get the Hubert embeddings. The output is a dictionary.
            # The 'last_hidden_state' key contains the embeddings.
            output = model(waveform)
            embeddings = output.last_hidden_state
            print("Embeddings extracted successfully.")
        except Exception as e:
            print(f"Error: Failed to process audio with Hubert model.")
            print(f"Input tensor shape at error: {waveform.shape}") # Print shape right before error
            print(f"Exception: {e}")
            return None

    # Convert the embeddings to a numpy array
    # Output shape is (batch_size, sequence_length_out, hidden_size)
    embeddings_numpy = embeddings.squeeze(0).cpu().numpy()  # Remove batch dimension
    print(f"Embeddings numpy shape: {embeddings_numpy.shape}")

    # Save the embeddings to a .npy file
    audio_file_name = os.path.splitext(os.path.basename(audio_file_path))[0]
    output_file_path = os.path.join(output_dir, f"{audio_file_name}_hubert_embeddings.npy")
    try:
        np.save(output_file_path, embeddings_numpy)
        print(f"Saved embeddings to {output_file_path}")
    except Exception as e:
        print(f"Error: Failed to save embeddings to {output_file_path}")
        print(f"Exception: {e}")
        return None # Return None if saving fails

    return embeddings_numpy

if __name__ == "__main__":

    for person in range(4, 43):
        if person == 26:
            continue
        robot_first_interaction = df_user.loc[df_user["PID"] == person, "Q1-Robot"].values[0]
        embeddings = []    
        turn = []
        df = pd.read_excel(f"data/text/P{person}/text-aligned-P{person}.xlsx", header=0)
        for i, row in df.iterrows():
            audio = f"data/audio_vad_500/P{person}/trimmed_audio-P{person}-{robot_first_interaction}-{i+1}.wav"
            # Check if the audio file exists
            if not os.path.exists(audio):
                print(f"Audio file {audio} does not exist. Skipping.")
                continue
            # Check audio duration in seconds from .wav file
            audio_info = torchaudio.info(audio)
            duration = audio_info.num_frames / audio_info.sample_rate
            """if duration < 2:  # Check if the audio is less than 2 second
                print(f"Audio {audio} is too short ({duration:.2f} seconds). Skipping.")
                continue"""

            turn.append(i+1)

            embedding = extract_hubert_embeddings(audio)
            if embedding is not None:
                embeddings.append(np.mean(embedding, axis=0))  # Average the embeddings across time
            else:
                print(f"Failed to extract embedding for {audio}")
        # Save all embeddings for the personxrobot
        os.makedirs(f"data/audio-embeddings-vad-500-lg", exist_ok=True)
        df_out = pd.DataFrame()
        df_out["Utterance ID"] = turn
        df_out = pd.concat([df_out, pd.DataFrame(embeddings)], axis=1)
        # Save the DataFrame to a CSV file
        df_out.to_csv(f"data/audio-embeddings-vad-500-lg/audio-dataset{robot_first_interaction}-P{person}.csv", index=False)
        print(f"Saved embeddings for {robot_first_interaction} P{person} to CSV.")
# Out:
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-1.wav...
# Audio loaded. Initial shape: torch.Size([1, 60160]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 30080])
# Squeezed waveform shape: torch.Size([30080])
# Final waveform shape for model: torch.Size([1, 30080])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (93, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-1_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-2.wav...
# Audio loaded. Initial shape: torch.Size([1, 64640]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 32320])
# Squeezed waveform shape: torch.Size([32320])
# Final waveform shape for model: torch.Size([1, 32320])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (100, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-2_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-3.wav...
# Audio loaded. Initial shape: torch.Size([1, 118432]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 59216])
# Squeezed waveform shape: torch.Size([59216])
# Final waveform shape for model: torch.Size([1, 59216])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (184, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-3_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-4.wav...
# Audio loaded. Initial shape: torch.Size([1, 104032]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 52016])
# Squeezed waveform shape: torch.Size([52016])
# Final waveform shape for model: torch.Size([1, 52016])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (162, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-4_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-5.wav...
# Audio loaded. Initial shape: torch.Size([1, 27520]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 13760])
# Squeezed waveform shape: torch.Size([13760])
# Final waveform shape for model: torch.Size([1, 13760])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (42, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-5_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-6.wav...
# Audio loaded. Initial shape: torch.Size([1, 440000]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 220000])
# Squeezed waveform shape: torch.Size([220000])
# Final waveform shape for model: torch.Size([1, 220000])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (687, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-6_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-7.wav...
# Audio loaded. Initial shape: torch.Size([1, 55040]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 27520])
# Squeezed waveform shape: torch.Size([27520])
# Final waveform shape for model: torch.Size([1, 27520])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (85, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-7_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-8.wav...
# Audio loaded. Initial shape: torch.Size([1, 116800]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 58400])
# Squeezed waveform shape: torch.Size([58400])
# Final waveform shape for model: torch.Size([1, 58400])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (182, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-8_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-9.wav...
# Audio loaded. Initial shape: torch.Size([1, 482976]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 241488])
# Squeezed waveform shape: torch.Size([241488])
# Final waveform shape for model: torch.Size([1, 241488])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (754, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-9_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-10.wav...
# Audio loaded. Initial shape: torch.Size([1, 50240]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 25120])
# Squeezed waveform shape: torch.Size([25120])
# Final waveform shape for model: torch.Size([1, 25120])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (78, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-10_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-11.wav...
# Audio loaded. Initial shape: torch.Size([1, 152576]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 76288])
# Squeezed waveform shape: torch.Size([76288])
# Final waveform shape for model: torch.Size([1, 76288])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (238, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-11_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-12.wav...
# Audio loaded. Initial shape: torch.Size([1, 63680]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 31840])
# Squeezed waveform shape: torch.Size([31840])
# Final waveform shape for model: torch.Size([1, 31840])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (99, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-12_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-13.wav...
# Audio loaded. Initial shape: torch.Size([1, 67520]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 33760])
# Squeezed waveform shape: torch.Size([33760])
# Final waveform shape for model: torch.Size([1, 33760])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (105, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-13_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-14.wav...
# Audio loaded. Initial shape: torch.Size([1, 129280]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 64640])
# Squeezed waveform shape: torch.Size([64640])
# Final waveform shape for model: torch.Size([1, 64640])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (201, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-14_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-15.wav...
# Audio loaded. Initial shape: torch.Size([1, 107200]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 53600])
# Squeezed waveform shape: torch.Size([53600])
# Final waveform shape for model: torch.Size([1, 53600])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (167, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-15_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-16.wav...
# Audio loaded. Initial shape: torch.Size([1, 329152]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 164576])
# Squeezed waveform shape: torch.Size([164576])
# Final waveform shape for model: torch.Size([1, 164576])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (514, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-16_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-17.wav...
# Audio loaded. Initial shape: torch.Size([1, 62080]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 31040])
# Squeezed waveform shape: torch.Size([31040])
# Final waveform shape for model: torch.Size([1, 31040])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (96, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-17_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-18.wav...
# Audio loaded. Initial shape: torch.Size([1, 265312]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 132656])
# Squeezed waveform shape: torch.Size([132656])
# Final waveform shape for model: torch.Size([1, 132656])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (414, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-18_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-19.wav...
# Audio loaded. Initial shape: torch.Size([1, 345280]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 172640])
# Squeezed waveform shape: torch.Size([172640])
# Final waveform shape for model: torch.Size([1, 172640])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (539, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-19_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-20.wav...
# Audio loaded. Initial shape: torch.Size([1, 170560]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 85280])
# Squeezed waveform shape: torch.Size([85280])
# Final waveform shape for model: torch.Size([1, 85280])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (266, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-20_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-21.wav...
# Audio loaded. Initial shape: torch.Size([1, 77440]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 38720])
# Squeezed waveform shape: torch.Size([38720])
# Final waveform shape for model: torch.Size([1, 38720])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (120, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-21_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-22.wav...
# Audio loaded. Initial shape: torch.Size([1, 215680]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 107840])
# Squeezed waveform shape: torch.Size([107840])
# Final waveform shape for model: torch.Size([1, 107840])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (336, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-22_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-23.wav...
# Audio loaded. Initial shape: torch.Size([1, 82464]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 41232])
# Squeezed waveform shape: torch.Size([41232])
# Final waveform shape for model: torch.Size([1, 41232])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (128, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-23_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-24.wav...
# Audio loaded. Initial shape: torch.Size([1, 126080]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 63040])
# Squeezed waveform shape: torch.Size([63040])
# Final waveform shape for model: torch.Size([1, 63040])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (196, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-24_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-25.wav...
# Audio loaded. Initial shape: torch.Size([1, 312320]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 156160])
# Squeezed waveform shape: torch.Size([156160])
# Final waveform shape for model: torch.Size([1, 156160])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (487, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-25_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-26.wav...
# Audio loaded. Initial shape: torch.Size([1, 635744]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 317872])
# Squeezed waveform shape: torch.Size([317872])
# Final waveform shape for model: torch.Size([1, 317872])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (993, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-26_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P4/trimmed_audio-P4-Alice-27.wav...
# Audio loaded. Initial shape: torch.Size([1, 135840]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 67920])
# Squeezed waveform shape: torch.Size([67920])
# Final waveform shape for model: torch.Size([1, 67920])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (212, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P4-Alice-27_hubert_embeddings.npy
# Audio file data/audio_vad_500/P4/trimmed_audio-P4-Alice-28.wav does not exist. Skipping.
# Saved embeddings for Alice P4 to CSV.
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-1.wav...
# Audio loaded. Initial shape: torch.Size([1, 34912]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 17456])
# Squeezed waveform shape: torch.Size([17456])
# Final waveform shape for model: torch.Size([1, 17456])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (54, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-1_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-2.wav...
# Audio loaded. Initial shape: torch.Size([1, 109984]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 54992])
# Squeezed waveform shape: torch.Size([54992])
# Final waveform shape for model: torch.Size([1, 54992])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (171, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-2_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-3.wav...
# Audio loaded. Initial shape: torch.Size([1, 118880]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 59440])
# Squeezed waveform shape: torch.Size([59440])
# Final waveform shape for model: torch.Size([1, 59440])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (185, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-3_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-4.wav...
# Audio loaded. Initial shape: torch.Size([1, 246272]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 123136])
# Squeezed waveform shape: torch.Size([123136])
# Final waveform shape for model: torch.Size([1, 123136])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (384, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-4_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-5.wav...
# Audio loaded. Initial shape: torch.Size([1, 206720]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 103360])
# Squeezed waveform shape: torch.Size([103360])
# Final waveform shape for model: torch.Size([1, 103360])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (322, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-5_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-6.wav...
# Audio loaded. Initial shape: torch.Size([1, 390496]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 195248])
# Squeezed waveform shape: torch.Size([195248])
# Final waveform shape for model: torch.Size([1, 195248])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (609, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-6_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-7.wav...
# Audio loaded. Initial shape: torch.Size([1, 371520]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 185760])
# Squeezed waveform shape: torch.Size([185760])
# Final waveform shape for model: torch.Size([1, 185760])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (580, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-7_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-8.wav...
# Audio loaded. Initial shape: torch.Size([1, 441088]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 220544])
# Squeezed waveform shape: torch.Size([220544])
# Final waveform shape for model: torch.Size([1, 220544])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (688, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-8_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-9.wav...
# Audio loaded. Initial shape: torch.Size([1, 289280]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 144640])
# Squeezed waveform shape: torch.Size([144640])
# Final waveform shape for model: torch.Size([1, 144640])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (451, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-9_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-10.wav...
# Audio loaded. Initial shape: torch.Size([1, 830304]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 415152])
# Squeezed waveform shape: torch.Size([415152])
# Final waveform shape for model: torch.Size([1, 415152])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1297, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-10_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-11.wav...
# Audio loaded. Initial shape: torch.Size([1, 21536]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 10768])
# Squeezed waveform shape: torch.Size([10768])
# Final waveform shape for model: torch.Size([1, 10768])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (33, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-11_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-12.wav...
# Audio loaded. Initial shape: torch.Size([1, 391040]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 195520])
# Squeezed waveform shape: torch.Size([195520])
# Final waveform shape for model: torch.Size([1, 195520])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (610, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-12_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-13.wav...
# Audio loaded. Initial shape: torch.Size([1, 940544]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 470272])
# Squeezed waveform shape: torch.Size([470272])
# Final waveform shape for model: torch.Size([1, 470272])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1469, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-13_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-14.wav...
# Audio loaded. Initial shape: torch.Size([1, 51264]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 25632])
# Squeezed waveform shape: torch.Size([25632])
# Final waveform shape for model: torch.Size([1, 25632])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (79, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-14_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-15.wav...
# Audio loaded. Initial shape: torch.Size([1, 86944]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 43472])
# Squeezed waveform shape: torch.Size([43472])
# Final waveform shape for model: torch.Size([1, 43472])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (135, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-15_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-16.wav...
# Audio loaded. Initial shape: torch.Size([1, 146528]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 73264])
# Squeezed waveform shape: torch.Size([73264])
# Final waveform shape for model: torch.Size([1, 73264])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (228, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-16_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-17.wav...
# Audio loaded. Initial shape: torch.Size([1, 99520]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 49760])
# Squeezed waveform shape: torch.Size([49760])
# Final waveform shape for model: torch.Size([1, 49760])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (155, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-17_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-18.wav...
# Audio loaded. Initial shape: torch.Size([1, 189472]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 94736])
# Squeezed waveform shape: torch.Size([94736])
# Final waveform shape for model: torch.Size([1, 94736])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (295, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-18_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-19.wav...
# Audio loaded. Initial shape: torch.Size([1, 201568]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 100784])
# Squeezed waveform shape: torch.Size([100784])
# Final waveform shape for model: torch.Size([1, 100784])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (314, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-19_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-20.wav...
# Audio loaded. Initial shape: torch.Size([1, 795872]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 397936])
# Squeezed waveform shape: torch.Size([397936])
# Final waveform shape for model: torch.Size([1, 397936])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1243, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-20_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P5/trimmed_audio-P5-Clara-21.wav...
# Audio loaded. Initial shape: torch.Size([1, 18560]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 9280])
# Squeezed waveform shape: torch.Size([9280])
# Final waveform shape for model: torch.Size([1, 9280])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (28, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P5-Clara-21_hubert_embeddings.npy
# Saved embeddings for Clara P5 to CSV.
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-1.wav...
# Audio loaded. Initial shape: torch.Size([1, 29728]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 14864])
# Squeezed waveform shape: torch.Size([14864])
# Final waveform shape for model: torch.Size([1, 14864])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (46, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-1_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-2.wav...
# Audio loaded. Initial shape: torch.Size([1, 116800]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 58400])
# Squeezed waveform shape: torch.Size([58400])
# Final waveform shape for model: torch.Size([1, 58400])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (182, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-2_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-3.wav...
# Audio loaded. Initial shape: torch.Size([1, 268992]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 134496])
# Squeezed waveform shape: torch.Size([134496])
# Final waveform shape for model: torch.Size([1, 134496])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (420, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-3_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-4.wav...
# Audio loaded. Initial shape: torch.Size([1, 549856]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 274928])
# Squeezed waveform shape: torch.Size([274928])
# Final waveform shape for model: torch.Size([1, 274928])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (858, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-4_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-5.wav...
# Audio loaded. Initial shape: torch.Size([1, 526496]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 263248])
# Squeezed waveform shape: torch.Size([263248])
# Final waveform shape for model: torch.Size([1, 263248])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (822, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-5_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-6.wav...
# Audio loaded. Initial shape: torch.Size([1, 336896]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 168448])
# Squeezed waveform shape: torch.Size([168448])
# Final waveform shape for model: torch.Size([1, 168448])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (526, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-6_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-7.wav...
# Audio loaded. Initial shape: torch.Size([1, 1348288]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 674144])
# Squeezed waveform shape: torch.Size([674144])
# Final waveform shape for model: torch.Size([1, 674144])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (2106, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-7_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-8.wav...
# Audio loaded. Initial shape: torch.Size([1, 966208]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 483104])
# Squeezed waveform shape: torch.Size([483104])
# Final waveform shape for model: torch.Size([1, 483104])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1509, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-8_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-9.wav...
# Audio loaded. Initial shape: torch.Size([1, 909472]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 454736])
# Squeezed waveform shape: torch.Size([454736])
# Final waveform shape for model: torch.Size([1, 454736])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1420, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-9_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-10.wav...
# Audio loaded. Initial shape: torch.Size([1, 750464]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 375232])
# Squeezed waveform shape: torch.Size([375232])
# Final waveform shape for model: torch.Size([1, 375232])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1172, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-10_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-11.wav...
# Audio loaded. Initial shape: torch.Size([1, 47680]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 23840])
# Squeezed waveform shape: torch.Size([23840])
# Final waveform shape for model: torch.Size([1, 23840])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (74, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-11_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-12.wav...
# Audio loaded. Initial shape: torch.Size([1, 192512]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 96256])
# Squeezed waveform shape: torch.Size([96256])
# Final waveform shape for model: torch.Size([1, 96256])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (300, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-12_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-13.wav...
# Audio loaded. Initial shape: torch.Size([1, 995680]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 497840])
# Squeezed waveform shape: torch.Size([497840])
# Final waveform shape for model: torch.Size([1, 497840])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1555, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-13_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P6/trimmed_audio-P6-Clara-14.wav...
# Audio loaded. Initial shape: torch.Size([1, 65792]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 32896])
# Squeezed waveform shape: torch.Size([32896])
# Final waveform shape for model: torch.Size([1, 32896])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (102, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P6-Clara-14_hubert_embeddings.npy
# Audio file data/audio_vad_500/P6/trimmed_audio-P6-Clara-15.wav does not exist. Skipping.
# Saved embeddings for Clara P6 to CSV.
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-1.wav...
# Audio loaded. Initial shape: torch.Size([1, 138336]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 69168])
# Squeezed waveform shape: torch.Size([69168])
# Final waveform shape for model: torch.Size([1, 69168])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (215, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-1_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-2.wav...
# Audio loaded. Initial shape: torch.Size([1, 260480]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 130240])
# Squeezed waveform shape: torch.Size([130240])
# Final waveform shape for model: torch.Size([1, 130240])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (406, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-2_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-3.wav...
# Audio loaded. Initial shape: torch.Size([1, 528640]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 264320])
# Squeezed waveform shape: torch.Size([264320])
# Final waveform shape for model: torch.Size([1, 264320])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (825, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-3_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-4.wav...
# Audio loaded. Initial shape: torch.Size([1, 149952]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 74976])
# Squeezed waveform shape: torch.Size([74976])
# Final waveform shape for model: torch.Size([1, 74976])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (234, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-4_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-5.wav...
# Audio loaded. Initial shape: torch.Size([1, 474016]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 237008])
# Squeezed waveform shape: torch.Size([237008])
# Final waveform shape for model: torch.Size([1, 237008])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (740, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-5_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-6.wav...
# Audio loaded. Initial shape: torch.Size([1, 102400]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 51200])
# Squeezed waveform shape: torch.Size([51200])
# Final waveform shape for model: torch.Size([1, 51200])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (159, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-6_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-7.wav...
# Audio loaded. Initial shape: torch.Size([1, 733024]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 366512])
# Squeezed waveform shape: torch.Size([366512])
# Final waveform shape for model: torch.Size([1, 366512])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1145, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-7_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-8.wav...
# Audio loaded. Initial shape: torch.Size([1, 190208]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 95104])
# Squeezed waveform shape: torch.Size([95104])
# Final waveform shape for model: torch.Size([1, 95104])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (296, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-8_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-9.wav...
# Audio loaded. Initial shape: torch.Size([1, 142080]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 71040])
# Squeezed waveform shape: torch.Size([71040])
# Final waveform shape for model: torch.Size([1, 71040])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (221, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-9_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-10.wav...
# Audio loaded. Initial shape: torch.Size([1, 163552]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 81776])
# Squeezed waveform shape: torch.Size([81776])
# Final waveform shape for model: torch.Size([1, 81776])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (255, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-10_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-11.wav...
# Audio loaded. Initial shape: torch.Size([1, 717344]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 358672])
# Squeezed waveform shape: torch.Size([358672])
# Final waveform shape for model: torch.Size([1, 358672])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1120, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-11_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-12.wav...
# Audio loaded. Initial shape: torch.Size([1, 514272]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 257136])
# Squeezed waveform shape: torch.Size([257136])
# Final waveform shape for model: torch.Size([1, 257136])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (803, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-12_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-13.wav...
# Audio loaded. Initial shape: torch.Size([1, 528320]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 264160])
# Squeezed waveform shape: torch.Size([264160])
# Final waveform shape for model: torch.Size([1, 264160])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (825, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-13_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-14.wav...
# Audio loaded. Initial shape: torch.Size([1, 363264]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 181632])
# Squeezed waveform shape: torch.Size([181632])
# Final waveform shape for model: torch.Size([1, 181632])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (567, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-14_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-15.wav...
# Audio loaded. Initial shape: torch.Size([1, 738368]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 369184])
# Squeezed waveform shape: torch.Size([369184])
# Final waveform shape for model: torch.Size([1, 369184])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1153, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-15_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-16.wav...
# Audio loaded. Initial shape: torch.Size([1, 99200]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 49600])
# Squeezed waveform shape: torch.Size([49600])
# Final waveform shape for model: torch.Size([1, 49600])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (154, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P7-Clara-16_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P7/trimmed_audio-P7-Clara-17.wav...
# Audio loaded. Initial shape: torch.Size([1, 721024]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 360512])
# Squeezed waveform shape: torch.Size([360512])
# Final waveform shape for model: torch.Size([1, 360512])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (1126, 1024)
# ...
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-4.wav...
# Audio loaded. Initial shape: torch.Size([1, 203840]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 101920])
# Squeezed waveform shape: torch.Size([101920])
# Final waveform shape for model: torch.Size([1, 101920])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (318, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-4_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-5.wav...
# Audio loaded. Initial shape: torch.Size([1, 208960]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 104480])
# Squeezed waveform shape: torch.Size([104480])
# Final waveform shape for model: torch.Size([1, 104480])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (326, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-5_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-6.wav...
# Audio loaded. Initial shape: torch.Size([1, 364096]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 182048])
# Squeezed waveform shape: torch.Size([182048])
# Final waveform shape for model: torch.Size([1, 182048])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (568, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-6_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-7.wav...
# Audio loaded. Initial shape: torch.Size([1, 199648]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 99824])
# Squeezed waveform shape: torch.Size([99824])
# Final waveform shape for model: torch.Size([1, 99824])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (311, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-7_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-8.wav...
# Audio loaded. Initial shape: torch.Size([1, 224960]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 112480])
# Squeezed waveform shape: torch.Size([112480])
# Final waveform shape for model: torch.Size([1, 112480])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (351, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-8_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-9.wav...
# Audio loaded. Initial shape: torch.Size([1, 235616]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 117808])
# Squeezed waveform shape: torch.Size([117808])
# Final waveform shape for model: torch.Size([1, 117808])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (367, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-9_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-10.wav...
# Audio loaded. Initial shape: torch.Size([1, 195424]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 97712])
# Squeezed waveform shape: torch.Size([97712])
# Final waveform shape for model: torch.Size([1, 97712])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (305, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-10_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-11.wav...
# Audio loaded. Initial shape: torch.Size([1, 105920]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 52960])
# Squeezed waveform shape: torch.Size([52960])
# Final waveform shape for model: torch.Size([1, 52960])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (165, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-11_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-12.wav...
# Audio loaded. Initial shape: torch.Size([1, 184640]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 92320])
# Squeezed waveform shape: torch.Size([92320])
# Final waveform shape for model: torch.Size([1, 92320])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (288, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-12_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-13.wav...
# Audio loaded. Initial shape: torch.Size([1, 185920]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 92960])
# Squeezed waveform shape: torch.Size([92960])
# Final waveform shape for model: torch.Size([1, 92960])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (290, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-13_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-14.wav...
# Audio loaded. Initial shape: torch.Size([1, 240736]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 120368])
# Squeezed waveform shape: torch.Size([120368])
# Final waveform shape for model: torch.Size([1, 120368])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (375, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-14_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-15.wav...
# Audio loaded. Initial shape: torch.Size([1, 397760]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 198880])
# Squeezed waveform shape: torch.Size([198880])
# Final waveform shape for model: torch.Size([1, 198880])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (621, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-15_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-16.wav...
# Audio loaded. Initial shape: torch.Size([1, 332480]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 166240])
# Squeezed waveform shape: torch.Size([166240])
# Final waveform shape for model: torch.Size([1, 166240])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (519, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-16_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-17.wav...
# Audio loaded. Initial shape: torch.Size([1, 203200]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 101600])
# Squeezed waveform shape: torch.Size([101600])
# Final waveform shape for model: torch.Size([1, 101600])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (317, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-17_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-18.wav...
# Audio loaded. Initial shape: torch.Size([1, 129280]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 64640])
# Squeezed waveform shape: torch.Size([64640])
# Final waveform shape for model: torch.Size([1, 64640])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (201, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-18_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-19.wav...
# Audio loaded. Initial shape: torch.Size([1, 512960]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 256480])
# Squeezed waveform shape: torch.Size([256480])
# Final waveform shape for model: torch.Size([1, 256480])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (801, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-19_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-20.wav...
# Audio loaded. Initial shape: torch.Size([1, 399904]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 199952])
# Squeezed waveform shape: torch.Size([199952])
# Final waveform shape for model: torch.Size([1, 199952])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (624, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-20_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-21.wav...
# Audio loaded. Initial shape: torch.Size([1, 282880]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 141440])
# Squeezed waveform shape: torch.Size([141440])
# Final waveform shape for model: torch.Size([1, 141440])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (441, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-21_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-22.wav...
# Audio loaded. Initial shape: torch.Size([1, 132768]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 66384])
# Squeezed waveform shape: torch.Size([66384])
# Final waveform shape for model: torch.Size([1, 66384])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (207, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-22_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-23.wav...
# Audio loaded. Initial shape: torch.Size([1, 93440]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 46720])
# Squeezed waveform shape: torch.Size([46720])
# Final waveform shape for model: torch.Size([1, 46720])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (145, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-23_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-24.wav...
# Audio loaded. Initial shape: torch.Size([1, 126400]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 63200])
# Squeezed waveform shape: torch.Size([63200])
# Final waveform shape for model: torch.Size([1, 63200])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (197, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-24_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-25.wav...
# Audio loaded. Initial shape: torch.Size([1, 46816]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 23408])
# Squeezed waveform shape: torch.Size([23408])
# Final waveform shape for model: torch.Size([1, 23408])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (72, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-25_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-26.wav...
# Audio loaded. Initial shape: torch.Size([1, 71360]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 35680])
# Squeezed waveform shape: torch.Size([35680])
# Final waveform shape for model: torch.Size([1, 35680])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (111, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-26_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-27.wav...
# Audio loaded. Initial shape: torch.Size([1, 271200]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 135600])
# Squeezed waveform shape: torch.Size([135600])
# Final waveform shape for model: torch.Size([1, 135600])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (423, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-27_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-28.wav...
# Audio loaded. Initial shape: torch.Size([1, 230624]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 115312])
# Squeezed waveform shape: torch.Size([115312])
# Final waveform shape for model: torch.Size([1, 115312])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (360, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-28_hubert_embeddings.npy
# Loading Hubert model: facebook/hubert-large-ls960-ft...
# Model loaded successfully.
# Loading audio file: data/audio_vad_500/P42/trimmed_audio-P42-Alice-29.wav...
# Audio loaded. Initial shape: torch.Size([1, 170784]), Sample rate: 32000
# Resampling audio from 32000 Hz to 16000 Hz...
# Resampled audio shape: torch.Size([1, 85392])
# Squeezed waveform shape: torch.Size([85392])
# Final waveform shape for model: torch.Size([1, 85392])
# Extracting embeddings...
# Embeddings extracted successfully.
# Embeddings numpy shape: (266, 1024)
# Saved embeddings to audio-embeddings/trimmed_audio-P42-Alice-29_hubert_embeddings.npy
# Audio file data/audio_vad_500/P42/trimmed_audio-P42-Alice-30.wav does not exist. Skipping.
# Saved embeddings for Alice P42 to CSV.

# %%
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

for person_id in range(4, 43):
    if person_id == 26:
        continue
    robot_first_interaction = df_user.loc[df_user["PID"] == person_id, "Q1-Robot"].values[0]
    embeddings_1 = pd.read_csv(f"data/audio-embeddings/audio-dataset{robot_first_interaction}-P{person_id}.csv", header=0)
    embeddings_2 = pd.read_csv(f"data/audio-embeddings2/audio-dataset{robot_first_interaction}-P{person_id}.csv", header=0)

    # Calculate cosine similarity between the two sets of embeddings only when they have the same number of rows
    if embeddings_1.shape[0] != embeddings_2.shape[0]:
        print(f"Warning: Different number of rows for {robot_first_interaction} P{person_id}. Skipping similarity calculation.")
        continue
    # Calculate cosine similarity (1 value per row)
    # Ensure the embeddings are in the same order
    embeddings_1 = embeddings_1.sort_values(by="Utterance ID").reset_index(drop=True)
    embeddings_2 = embeddings_2.sort_values(by="Utterance ID").reset_index(drop=True)
    similarity_matrix = cosine_similarity(embeddings_1.iloc[:, 1:].values, embeddings_2.iloc[:, 1:].values)
    per_row_sim = np.diagonal(similarity_matrix)
    # print(f"Cosine similarity for {robot_first_interaction} P{person_id}: {per_row_sim}")

    # check for values lower than 0.95 and print the corresponding row numbers
    low_similarity_indices = np.where(per_row_sim < 0.95)[0]
    if len(low_similarity_indices) > 0:
        print(f"Low similarity values for {robot_first_interaction} P{person_id}:")
        for index in low_similarity_indices:
            print(f"Row {index + 1}: {per_row_sim[index]:.4f}")
# Out:
# Low similarity values for Alice P13:
# Row 11: 0.7840
# Low similarity values for Alice P24:
# Row 2: 0.7350
# Low similarity values for Clara P40:
# Row 3: 0.9496
