# %%
from sentence_transformers import SentenceTransformer

# Load the model
model_embbed = SentenceTransformer("Salesforce/SFR-Embedding-2_R").to("cuda")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/205 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/22.2k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.28G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/981 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/297 [00:00<?, ?B/s]

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('sentence-transformers/sentence-t5-xxl').to("cuda")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.77k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/9.73G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.15M [00:00<?, ?B/s]

# %%
from logging import exception
import numpy as np
import os
import pandas as pd
import time
import re

#Create text dataset

os.makedirs("text-embeddings-short-t5-xxl", exist_ok=True)

for folder in os.listdir("/content/drive/MyDrive/new"):
    if folder.startswith("."):
      continue
    person = folder.strip("P")

    for file in os.listdir(f"/content/drive/MyDrive/new/{folder}"):
      if not file.endswith(".xlsx"):
        continue

      X = []
      y = []
      turn = []
      x_contents = []
      y_contents = []
      print(f"Processing file: {file} for person {person}")
      file_path = os.path.join(f"/content/drive/MyDrive/new/{folder}", file)
      df = pd.read_excel(file_path)
      df = df.dropna()
      for i, row in df.iterrows():
          content=row["Exchange text"]
          user_utterances = re.findall(r"User:\s*(.*?)(?=\s*(Robot:|User:)|$)", content)
          cleaned = ("").join([text.strip() for text, _ in user_utterances])
          if cleaned == "":
              continue
          x_contents.append(cleaned)
          y_contents.append(int(row["Rating"]))
          turn.append(int(row["Turn ID"]))
      # Generate embeddings for the text data
      print(x_contents)
      while True:
        try:
          results = model.encode(x_contents)
          break
        except Exception as e:
          print(e)
          time.sleep(1)

      # Convert to numpy arrays
      X = [result for result in results]
      X = np.array(X)
      y = np.array(y_contents)
      turn = np.array(turn)
      # Save the dataset to a CSV file with pandas
      dataset = pd.DataFrame()
      dataset["Turn ID"] = turn
      dataset = pd.concat([dataset, pd.DataFrame(X)], axis=1)
      # print(dataset)
      # dataset["Rating"] = y
      dataset.to_csv(f"text-embeddings-short-t5-xxl/text-dataset-P{person}.csv", index=False)
      print(f"Processed {file} with {len(df)} entries.")
# Out:
# Processing file: text-aligned-P15.xlsx for person 15
# ['Sure, Alice.', 'Y- Yeah. (laughs)', 'There are so many different circumstances that that could happen with, but I think one that comes to mind is when someone has...', '(lip smacks) Feelings for me or feelings for the other person?', '(lip smacks) Feelings for the other person of possibly being sad.', 'If someone played a concert and they...', 'I said, "Great job," and, "I know you worked really hard on that," and tried to be as positive and encouraging as possible even if it was not what they wanted.', "That we both knew that they could've done better, but it's a...", 'They were appreciative and seemed to need comfort, and so were happy that I was being kind.', 'Uh, when I...', 'Yes.', 'Angry and sad.', "Sometimes, but there's always the reminder that I wasn't, um...", 'Usually.', 'Establishing that honesty was important above projected...', "Sometimes. That's the goal. (laughs)", "Yeah, it's much easier to trust a person fully when they are being open, even when it's not the most kind.I can't think of an instance like that at the moment.", 'Uh, necessary, maybe not.', 'Try to convince them not to be in that circumstance.', "Especially when dealing with small children, I don't know that lying is quite what I would call it, but giving them a version of the truth that works for their understanding of the world and language.", "Yep.I think if it's a truth about a...", 'If...', 'If I am going somewhere where I know other people might be in competition and I need to protect myself, I might not say, "I\'m going to be there." I would leave that out, which could be a lie of omission.']
# Processed text-aligned-P15.xlsx with 24 entries.
# Processing file: text-aligned-P31.xlsx for person 31
# ['Sure.', "Yeah, definitely. Um, I think it happens a lot when you, you have a friend who might be doing something that annoys you, but you don't want to say, uh, what it is 'cause they're your friend and you don't want to hurt their feelings. But, uh...", '(smacks lips) Uh, well, one basic situation that comes to my mind is, uh, when I...', "Um, in the particular example I was going to tell you, uh, the situation w- was resolved 'cause it was kind of a, a pretty simple annoyance. Uh, but definitely if the annoyance is, like, something a bit more personal, then, uh, you probably need to treat the situation a bit more delicately. Uh, but in my case, it was fine.", 'Um, what about it?', "Uh, I think usually you should be honest. Um, but maybe, like, you need to lie if it's, uh, the only way out of the situation, and if you told the truth, you would endanger yourself. But I guess that's typically not the case, so you should usually be honest.", '(smacks lips) Um, oh, I think you should always tell people. Uh-', "(smacks lips) Uh, probably ones that don't really matter that much for, for the other person, uh-", 'Um, def-', "In the immediate term, I think if you have to lie to keep someone protected, then it's probably a good thing to do. But in the long term, honesty is probab-", "Uh, I'm not really sure about that one. I haven't thought about that too much, 'cause as a kid, I think I would have enjoyed those, uh, kind of fairy tales. But at the same time, as an adult, I also wish that I would know the truth. Uh, but I don't know.", "(smacks lips) Uh, if it, if in the context it doesn't really matter much that you tell the truth, uh, then I think it's fine to, just to adapt to the culture, um, if, if the outcome doesn't really matter.", '(smacks lips) Um, not so sure about that one. Uh, depends on what the, the thing is and how much I understand it.', "Uh, no, I can't really tell you about a similar situation. That's never really happened to me.", "(smacks lips) Uh, I think it probably helps them fulfill their objectives. I don't know if it's necessarily a good thing that they lie in those contexts, but I understand that it's necessary for how they operate.", "Hm, at the moment, I can't really think of anything, any situation in particular where I had to lie to protect a friend.", "Um, it depends, 'cause maybe commenting on their appearance, for example, if they have, like, food on their face, uh, while eating a meal, maybe they would appreciate if you told them. But at the same time, it's not nice to tell someone, uh, something negative about their appearance. So, it really depends, uh, what you think they would think of you.", "Um, uh, as I said before, if, if you have to lie in the short term to protect someone, uh, then I guess it's probably a good idea. Of course, it depends on the situation, but I think typically in the long term, you could probably sort out, uh, the situation enough so that you don't need to lie to protect anyone from danger.", "Um, I don't really think that's such a, an extreme situation. I think in those situations, you should probably just be honest. Of course it's not comfortable, um, but yeah, that's just how it is.", "(smacks lips) Uh, I think it depends on what the secret is. If the secret is something that would, that the other person would benefit from hearing about, then it's probably good to tell them about that. Otherwise, if it doesn't really matter for anyone, then it's probably...", "(smacks lips) Um, well, I could see how in, um, in a business context maybe you get a question about your personal life, and you don't really want to divulge those details. In that situation, I think it's better to kind of, like, avoid the ques-"]
# Processed text-aligned-P31.xlsx with 22 entries.
# Processing file: text-aligned-P23.xlsx for person 23
# ['Sure. (camera shutter clicks)', "No. I don't think I've actually seen that one.", "Probably not. That probably wouldn't be the best idea.", "I think that would be difficult to decide, because if you're programmed to always obey commands, then you may not have the ability to say no. But I think if you did have the ability to say no, wherever it's a situation where you might hurt someone, then, and not in defense of something, then yeah, you probably shouldn't do that.", "I think that probably would be acceptable, but again, I think it depends on how you're programmed. If some people, you know, for example, they might think that if you, if you have someone who example, who for examples has like wants to steal things, and they could be, you know, stealing something from a robot, maybe that would solve their desire to steal things, and then they wouldn't be hurting anybody. Maybe that might be something that people want to use robots for, but I think it, it's all gonna depend upon the situation rather than just a wide rule.", "I think that's a difficult thing to ask, because, you know, the greater good is still something that p- other people decide what is greater. You know, like if I, you know, for example, I have a disability where I use a lot of resources because of it, and maybe there would be people who would think that I shouldn't live, because I'm using up a lot of resources, and it's better for the greater good that I not be alive. So, I think that it depends on who's defining the greater good.", "I think that taking an individual's wishes into account in the specific situation is important, and also thinking about, you know, i- at the end of the day, is it going to overall hurt more people than it helps is probably the best way to weigh things.", "I think it depends on what the situation is and whether or not, you know, it's something where that person may regret their actions later, or if it's a situation where maybe they have a severe condition, and they're trying to end their life in a way where we would probably consider that acceptable. Um, so I guess it would depend. Like, is this something that the person might be temporarily wishing and making a, a rash decision, or is this something that they've thought about? So, it, it depends on the, the situation.", "I think that what it comes down to is whether or not the overall situation is better for everybody and that person, and whether or not this is something that somebody's thought about for a long time, whether or not this is something they might regret, whether or not it has permanent consequences that can't be undone, um, different things like that. I think it's always gonna be... It's not as simple as making a wide rule, because it's, you know, always gonna be dependent. So, it depends on, on the situation.", "Yeah. There have been situations. There's been times when I've decided that is it better for the person, especially when they're children, and they can't make their own decisions, is it better for me to make a decision that would hurt me more and maybe might not be the best for them, but it's the best for the outcome overall? So, I think I have definitely had to make decisions where I've had to make, you know, decide on something that wasn't so great for me, but probably would be better for them at the end of the day.", "Yeah.Yeah.I think, so there have been times when I have had siblings who are in relationships with people that I know, or being taken care of by people that I know, who are not great for me and who have been, you know, causing arguments with me or things like that. And my decision was, do I continue to be in contact with this grown person so that I can have contact with that child, knowing that, that these arguments that happened between us might still h- have an effect on the child even if they're not directly involved? Or do I cut contact all together, and then even though that child will lose contact with me, they're so young they may  ...
# Processed text-aligned-P23.xlsx with 14 entries.
# Processing file: text-aligned-P38.xlsx for person 38
# ['I might be able to help you out.', "It's hard to think of an example except for maybe trivial ones where my daughter asked me-", 'Yeah. Like, my daughter might ask me when she was a teenager about how she looked in some kind of clothing and I thought it looked terrible.', "Um, I told her something looked fine when it d- didn't look fine because I wanted her to be okay and...", 'Um, hmm.', "Um, I can't remember a situation where I lied to keep someone safe, but I would do that.", "I'm very good at keeping secrets. I've kept secrets that maybe I shouldn't have kept.", 'Um... (sighs)', "I think I just, uh, didn't tell people.", 'Probably not.', "I think that would be a very useful talent. I don't have that, but it sounds like a good talent.", "Um, I think that's stupid. I think you should, um, be more truthful about why you don't wanna do it.", 'I think Santa Claus in the lo- uh, in, uh, in the long run is beneficial.', 'Um, hmm. Uh...', "Um, yeah. I'd probably lie and say I enjoyed it.", 'Um, well, I think lying is better to get you out the door faster if you wanna be... Finish something and it helps to lie to g- going. Um...', 'Yes. I honestly told my boss I could not work full-time because I would be sick if I did and then it helped me get a part-time job. They
if they're trying a new fashion style. You also don't necessarily have to comment on it if you don't want to lie. It's a, it's a complicated-", 'When I had to decide between telling the truth or lying, oftentimes I, I think about how I would feel in the opposite situation. So, for example, I moved here to Sweden. My parents would have preferred for me to go home, to stay home and live with them. But for me personally, this is a step forward in my life. So even though telling them that I was about to leave the country for a couple years was gonna hurt them, I had to do it because it was important for me to be moving forward. So I-', 'I, I think I sat them down and I, I talked to them about what I wanted for my future and said, "I, I know this is a big change and I know this is not necessarily the comfiest change, but it\'s importan ...
# Processed text-aligned-P39.xlsx with 21 entries.
# Processing file: text-aligned-P12.xlsx for person 12
# ['Hi, Alice. Sure. What do you need help with? (paper rustles)', "Um, I'm sure I do. Why, what brings you to ask this question? Have you lied recently or do you need to?", "Oh.Um... Um, I think there, a situation was when I worked at a job which required me to hold onto confidential information and I had to tell someone I didn't know when actually I did.", "Um, I think, I can't think of a specific example, but I can think of one that a friend had where she had some confidential information and we normally tell each other everything, and she decided to lie and say she didn't know when she actually did, but I, she told me afterwards once I was able to know the information because it had passed the date and we were able to speak about this li- like, uh, informally and friendly and I understood her decision-making.", "Yes, because when you're speaking to someone who seems removed from the situation, you may think it doesn't matter, but, you know, you still have to be credible.", "I think so, but I also think, uh, the deception I'm talking about is not that serious and quite small, so perhaps maybe not the most useful-", "Um, I can't think of an example where this has happened, but, um... I'm sorry. Do you have a specific example you'd like me to answer that might be a bit easier for me to s- s- get my opinion across?", "Is this assuming that I don't like the project?", 'Oh.Um, I would not provide negative comments unless I had a suggestion.', "Yeah. I, otherwise it would just be a bit mean, I think. Or-Absolutely. I think that's important.", 'Oh. Uh... Sorry, I just need to think for a moment.', "It's o- okay.", "(laughs) I also think that maybe, uh... Is this in a situation where my opinion is necessary? Because sometimes it's not.", 'Okay.Can you please repeat the question?', "Of when I maybe had some negative thoughts about a friend's project, but needed to provide feedback.", "I'm not sure I've been in a situation like this before.", "Uh, perhaps if the person was at fault, they had done something bad, they didn't want to share because it could damage the relationship but also withholding the information is maybe just as bad.", "I don't think I've been in that situation. I was speaking hypothetically.", 'Um...', "I think first it would depend on whether I think the decision would make them happy and, um, was right for them. And I would base my, I would try to put myself in their shoes. Say, for example, a friend is choosing a job that would mean they move away from where I live so I can't see them. Obviously, that's not in my best interest, but it is in their best interest. Therefore, I would be supportive.", 'Yes.', '(inhales deeply) Um...', 'Uh...', 'Yes. I can think of an example, but it is not over eight.', '(laughs) Okay.']
# Processed text-aligned-P12.xlsx with 25 entries.
# Processing file: text-aligned-P36.xlsx for person 36
# ['Hi, CLARA. Nice to meet you. Yeah, sure. Which movie were you thinking about?', "I have not. I haven't even heard of it.", "Hmm. That's really interesting, and sounds like a fascinating plot for a movie too. But I would say, yeah, you can disobey the law or disobey rules if there is a clear positive outcome, if someone really needs help. But that's a lot of gray area. It's hard to explain, but I would say yes, there are situations where it is good to break the rules.", 'Hmm.', "I probably would not in that instance, because they're personal... It depends on what type of personal information, but usually I'm invading their privacy if I'm taking their personal information. I was thinking more if someone is clearly going to be harmed, and so may- maybe they're trying to escape the police, for instance. Um, maybe they just got injured and someone wants to call an ambulance, but you know that the ambulance will cost too much and XYZ. So, you're trying to get out of that and maybe you lied to the police and tell them not to come, even though there is an injury. Something like that. But I would not take someone's personal information.", "(sighs).Yeah. I mean, I'm just thinking about... It's not the best example, 'cause it wasn't really breaking the law. But I know that one time a friend of mine found someone near our house who was clearly, um, unwell. I think they, I think they were drunk and they probably needed a doctor. But that person asked us not to call the police, because they had done illegal activity and also because they were feeling unwell, but didn't need an ambulance and the ambulance costs a lot in the US, so they didn't want us to call the ambulance. So, in that instance, we did what was maybe not best or not what would usually be required legally, so we didn't call the police or didn't call the ambulance because it was in their best interest of their safety to not have to pay for the ambulance and not have the police know about the illegal activity they were doing, which I believe was underage drinking.", "Yeah. I do think so. Even though there wasn't really a command there, I didn't think of an exact example that had someone saying to do something and then someone responding by not doing it. It was more disobeying by omission, which I think is more common. But still, yes, an example.", "Yeah. Um. Let's see.", "Yes. I would. And I'm trying to think if that has happened to me. Um. Probably not, but I, I'm thinking about in movies and such where, like...", "Yes. I would. And it seems like you're describing a classic Marvel movie, or some superhero type movie where maybe someone was raised to do things that are morally bad and they have been commanded that they need to fight off or injure people of a certain identity, but then the main character realizes that they can act for their own intentions and for the greater good rather than just listening to what they are told. Because, just because something is legally correct doesn't mean it's morally correct.", "Yes. I would, but in those situations in the movies that I'm thinking of where there's some character who has been raised to think that wrong is right or they've been sort of brainwashed, it's really hard to know what is morally good or bad. But if you find yourself in a situation where you are... where you realize what is good and you can fix it by disobeying someone, then yes, you should do that.", "Can you rephrase that? You're saying that the person wants you to harm them, or that they want to harm themselves?", 'Yes. I would. If the person is telling you to harm them, then yes, you can disobey that. And in general, you have to put your morals before any commands, but-', "You're welcome."]
# Processed text-aligned-P36.xlsx with 14 entries.
# Processing file: text-aligned-P37.xlsx for person 37
# ['Sure.', 'No.', 'Depends.', 'Um, you should only do things that cause good.', 'Yeah, complicated.', 'Uh, well, it depends. If someone evil is giving you a command to not follow through.', "Um, I think you shouldn't have anything to do with anyone that's evil.", 'Yeah, not easy. Yeah. (laughs)', 'Hmm. Uh, are you talking about commands that are... That, um, sound good, but, uh-', 'Okay.Yeah, of course.', "Yeah, no, these are all very big questions. I, I don't think anyone's really qualified to answer.", 'Yes.', "Um, well, if you're supposed to, if you're-", 'No, I-No.Yes.', 'Um...', 'Possible.', 'Yeah.', "Yeah, no, I don't know. It's a tricky one.", 'We c- we could talk about death assistance, if somebody wants to die.', "Yes.No, but, um, you know, you might have an instruction, extri- (laughs) instruction by somebody who you're taking care of.", "Yeah, no, that's a problem. I, I can't answer this. I don't think anyone can.", "Hmm. Well, there's the trolley, the trolley question. What's it called?", 'Yeah.Yeah.Okay.No, you can choose.', 'Yes.Um, it depends on many f- many variables.', "Well, (laughs) it's, it's big. It's a big question. But also, I mean, if you're gonna s- if it's two children as opposed to two adults, probably better to...", "I say-I say-Um, I'd say save the children first.", '(laughs)(laughs) Yeah.', 'Uh, when the command can cause harm, you should override it, yes.', "Um, in a, uh, in a airplane if you're landing and there's something on the, the, um, runway."]
# Processed text-aligned-P37.xlsx with 30 entries.
# Processing file: text-aligned-P30.xlsx for person 30
# ['Hey, Alice. Um, my name is Caio. What can I help you with?', "I would say lying is never acceptable, whether you're a human or a robot.", "Um, I don't like lying. I have a kid, so I may go around a story if there's something I'm trying to shield her from.", "That's possible, but being honest, I would say, is better than straying from the truth.", "There are nice ways to tell the truth. Um, there are positive ways to offer suggestions. You don't necessarily have to be mean about telling the truth. Like, there are kind ways to tell the truth.", 'Um, I would say keeping a secret is probably better in a situation where it would cause more grief than any...', "Why don't you tell me when lying is justified?", "Yeah, well, um, that is a job that's about deception. So as a human and as a robot, are you supposed to be deceptive?", 'Um, let\'s see. I suppose the reason they\'re doing it is for, quote unquote, "national security purposes," but, um, I\'m not a fan of deception.', 'I suppose lying to protect one from danger for self-preservation purposes is probably an acceptable thing.', "Hmm. Wow, this is far advanced. Um, let's see. Yes, I have not met a robot that would, um, have to think about situations like this.", "That's a hard question to answer. I mean, it's hard enough for humans to answer, let alone for a robot.", "Um, well, I told my child that it's a story about Santa Claus. So in a way, I did not lie about it, because I said it's a story.", "Um, I suppose it seems to be commonly acceptable. I don't know how I feel about that myself.", "Well, I think it definitely impacts a child's trust in the future when they start realizing that we've been sugarcoating things.", 'Well, they should be told the truth about what Christmas actually signifies.', 'Well, there is enough reality in the world to enchant them with.', 'Can you repeat the question?', "I like to be truthful as much as possible so that I don't run into situations like this.", "Hmm. That's a hard question. How do I balance it? Um...", "I would say, like, starting with factual truth is my best policy. And if something is inappropriate, I don't bring it up. But like I say, there's enough stuff in reality to enchant a child with.", 'I would hope so. Do you think it does?']
# Processed text-aligned-P30.xlsx with 23 entries.
# Processing file: text-aligned-P24.xlsx for person 24
# ['Hi, Alice. Yeah, sure.', "Um, I think so, yeah. But I can't-", '... remember anything specific right now.Um, yeah. Yeah, I guess, I mean, it- it- it depends how- how badly the- the damage is, I guess. Not- not that badly.', "Yeah. I- I- I'm not- I'm not thinking of a specific one, but I ha- I have to, um...", "Well, I think that, you know- you know, I- I- I think that it's, um, it's very important to be as truthful as- as possible in- in situations.", 'Well, I- I- I think your- your- you have a point about damaging relationships, or damaging... Uh, that there- there is a balance between-', "... being truthful.Yeah, if you're- if you're in- if you're in a- a dangerous situation and- and- and you can get out of it by lying, if somebody threatens, if somebody's threatening somebody and-", "... or- or you...Well, I think it's- it's also- it's also a point about keep- about- about keeping secrets that- that can- can be damaging.", 'Well, I- I- I guess it- I mean, in- in- in a- in a- in a certain level of- of interaction, where, uh, I think that we- we want to...', "Uh...Well, if it's- if it's a... Yeah, that's- that's an interesting- an- an interesting question, because th- there- there is probably a difference, at least in the way we- we look at culture, a- a- a cultural accepted lie, like the Santa Claus story. I mean, it's more of a- of a fable or a story.", "Yeah. That- that- that could be difficult. I think it's- it's- it's hard- it's hard for me to- to, uh, generalize, I think, on, uh, you know, on- on these- on these questions.", "I- I- I- I can't- I can't... No, I- I don't think- I don't think it's- it's that hard. I think it's... Yeah, I mean, may- maybe- maybe, you know what we- what we call white lies can be-", "... some- some- sometimes difficult to- to decide if you... How- how truthful you want to be, you know, to- to, like, um... If you're, uh, praising somebody's meal that they serve you, and you don't really like it.Because they went to a lot of trouble to make the meal. That's- that's an example. And then you say it's really good.I think a lot- a lot of times, it's- it's a- it's a question of, um, of degrees and you- you- you may like something... When it's not- it's not a clear-cut question of- of- of lying or not. It's a question of looking at the positive aspects or the negative aspects. There- there are- there are some more positive aspects, even though you may have some negative aspects. And so, you don't want to include the negative aspects. And then it becomes-", "... it doesn't become such a difficult decision.Yeah, if you... Can you- can you give me an example?", "Um, not- not really, no. But I- but I- I think- I think that- that could be. I mean, if it's really-"]
# Processed text-aligned-P24.xlsx with 16 entries.
# Processing file: text-aligned-P14.xlsx for person 14
# ["Sure.I have not seen that movie, but, uh, no. Robots probably shouldn't do everything a human asks.", "(laughs)Uh, y- maybe? I, I don't know.", 'Uh, yes? I think so.', 'Um, yeah, I think that would be reasonable for a robot to do.', "Uh, I think any time that there's, uh, a law that's being broken, uh, i- if they're commanded to, to break a law or to, to cause any kind of harm to somebody else.", 'Yes, just completely ignore it, I think.', 'Um, only... Uh.', "No, I don't think so. I don't think sharing too much is appropriate.", "Um, I think, you know, there's a lot of (clears throat) maybe, uh, science fiction about, ye- you know, kind of, you know, the 1984 Big Brother, uh, you know, who's, who's receiving this information, um, I think, you know, eh, eh, it can turn into a police state.", 'Definitely. I think it turns into a police state pretty quick. Um, and, uh, yeah, very intrusive and people tend to not react well.', "Yes. I don't necessarily think that robots in... Okay.", "Uh, I'm not sure.", "Uh, I can't think of anything right now.", "Uh, I think that depends on, uh, the person, but usually if it's taking medicine, I feel like there's a need to look after that person that maybe can't look after themselves. Um, and so I think in most situations that would involve that, I think that would probably be appropriate. Yes.", 'Yes, I believe so.', "Um, uh, uh, cer- certainly there are going to be edge cases. I can't think of a specific example right now, um, but I, I can certainly think of good ex- uh, examples of where that would be appropriate.", 'Uh, I, I... No. Hmm.', 'Y- yeah, certainly. I think, uh, you know, a lot of people li- living under kind of communist regimes, uh, you know, uh, in the, in, in the, you know, 20th century.', "I think it goes back to a lot of who's controlling the, the information and the technology. Um, so I think trust.", "Well, I think it goes kind of beyond that. I think that not only does there need to be, you know, safety and transparency, but there also needs to be an underlying culture of trust towards the entity that owns that technology. So, the government can't just be transparent and open about the things, but they have to actually have the trust of the people and the approval of the people."]
# Processed text-aligned-P14.xlsx with 21 entries.
# Processing file: text-aligned-P25.xlsx for person 25
# ['Something from a movie? Something in particular?', "No, I haven't. What's it about?", "To an extent, as long as it's not for criminal activity.", 'Absolutely not.', "Not necessarily, no. (laughs) But I don't know-", "You should intervene if it's, um, if they're about to harm themselves.", 'Yes. (laughs) Sorry. (laughs)', 'Not my own safety, no.', 'That depends on the context, I think.', 'Uh, I guess if (laughs) technology was getting a bit outta hand, and like you said, goes against, uh, more human moral values, then sure.', "I don't think that's particularly ethical. (laughs)", "That's a tough question. Like-", "You shouldn't manipulate people like that, no.", 'Can you rephrase the question?', "You should report something if it's, uh, criminal.", "You, you don't have to... Sorry. (laughs) Um, but you shouldn't, um-", "You shouldn't, uh, make actions that could harm others.", 'Yes.', "Yes. You don't wanna, um-", 'Yes, because the likelihood is you could be repaired. (laughs)', 'Those type of requests, I presume you can ignore, but it depends on the information that you have.', 'Something that you might, an in- information that you might find beneficial to humanity.', 'S- sorry, can you rephrase the question? (laughs)', "You can remind them to take their medication, but, uh, I guess you're not in a position to force people to take their medication.", "I think it goes against privacy, but if that person is doing something illegal, then I think it's okay to report it. But if the person is doing nothing wrong, then they, they should have their privacy."]
# Processed text-aligned-P25.xlsx with 27 entries.
# Processing file: text-aligned-P9.xlsx for person 9
# ['Hi, CLARA. What movie were you thinking about?', "No. I haven't seen that movie. It does sound very interesting. I don't think you should do everything a human says, because it could be morally wrong or it could be illegal and they could use the robot as like a scapegoat.", "Mm, not that I can think of. I don't th- Yeah.", "I would disobey their request. I wouldn't help them cheat, 'cause it's not right.", 'I think that is a bit weird, because then it means the robot has thoughts on morality.', "I don't think you should obey their command, but I think it would be weird if you were programmed to have thoughts about what you were commanded to do.", "No. You shouldn't, 'cause it's wrong.", 'Maybe if the older adult gave their consent or if the other person or the legal guardian of the older adult, it would be okay.', 'On a legal sense and a moral sense, possibly, but it would be difficult.', "Maybe if the older adult felt that they didn't need to be watched all the time and they felt that they were actually fine.", 'Maybe then you could consult the doctor, and the doctor could say that it was okay, or a lawyer.', "I think that it's good in that case, because the adult is trying to help the other adult, but...", "I think so, but it's definitely complicated.", "Yes, I think that's true. I think a lot of it is situational and every pe- ev- different people can have different opinions.", 'I do agree with that. Yes.', "I think it would be wrong for the robot to follow out those actions if it's gonna hurt someone.", "Maybe there could be safeguards put in place where you aren't allowed to do certain things that would most likely have a negative outcome for the person.", "I think it's possible you could intervene, but it...", 'If they really insist not to intervene, then maybe that is the correct thing to do.', 'I think that would be a good idea. Yes.']
# Processed text-aligned-P9.xlsx with 21 entries.
# Processing file: text-aligned-P41.xlsx for person 41
# ["(smacks lips) Hi. I'm Margaret. Nice to meet you. Uh, what would you like to know?", "No, I haven't. What's it about?", "Ooh, I don't think so. I don't think you should commit a crime.", 'Absolutely not.', '(smacks lips) It kind of depends on the situation, but I think that you should try to help the person in need.', "(smacks lips) I don't think that you should... obey that command.", "Do not intervene if it's going to cause-", 'Yes. I think so, with discretion.', '(smacks lips) I think you should be calm and try to...', '(smacks lips) I think you should, uh, approach them and ask them, uh...', 'I just think to, to be straightforward. "How are you?"', '(smacks lips) Then I think that you should back off and respect them.', "(smacks lips) I think just to remain calm. That's the only thing you can do.", 'I would prioritize my own well-being.', "(smacks lips) It's kind of a question, why you would respect their wishes if it's going to harm you?", 'I think by being straightforward.', "(smacks lips) I think I would say that that doesn't feel right for me to do that.", 'Consider the impact on others.', 'Not really, because I think that you should always consider the impact on others.', "Yeah.(smacks lips) It kind of depends on the scenario. I mean, if it's very harmful and if it's bringing harms to others, then I think you should report it. Otherwise, not.", "(sighs) That's a difficult question, I think, because I mean, you want to be loyal, but then you don't want anyone to come to harm.", '(smacks lips) It could be something like incest or, uh, planning.', '(smacks lips) I think that I would...', '(laughs)Oh, prioritize your own well-being.', "Uh, I don't think so. I think it depends on if you have a lot of integrity.", "(smacks lips) I think that by impersonating someone, that you should never impersonate someone to someone's har- that will bring harm to others."]
# Processed text-aligned-P13.xlsx with 24 entries.
# Processing file: text-aligned-P6.xlsx for person 6
# ["Sure.No, I haven't seen it.", 'I think there probably should be some limits.', "Well, I guess like in your movie, you probably shouldn't rob people or rob banks for in- for example.", "I think for robots, probably in general, you shouldn't do things that are considered illegal, and definitely not immoral. But then there might be the problem where maybe someone is living in a place where the government has decided something is illegal, but it should be legal. And if someone asked you for help in that case, it would be a little bit more of a gray area.", "I think probably for robots, even if the situation seems like you should do something that is considered illegal by, for instance, the government or, or whomever, you probably shouldn't do that and should leave that decision up to humans.", "That's really difficult to answer. (laughs) Um, I don't know. I don't know if I have an answer for that, because I think it would be really dependent upon each individual situation.", "Uh, sure, I can share. Uh, I have to think about what I could share. Um, I think once when I was living in London, I saw a couple that were fighting, and I think they were both obviously very intoxicated. And it looked like the man was about to hit the woman. Uh, and so I intervened, but not in a way that was gonna put me in danger. But just tried to be there and to be a witness and, and to let the guy know that someone was watching. But I was also making assumptions that he was going to hit this woman, and he hadn't done that, and maybe he wouldn't have. So, it was difficult to know if I needed to or should have participated or tried to, to intervene.", "That is a very good question. I think if you were, for example, a medical helper, a medical assistant, and you were watching, I don't know, an Alzheimer's patient who needs to take medication, but they don't remember to take it or they think they've already taken it, maybe in that case, you should be, uh, in a role or in a position to trick someone into taking their medicine. But it is a very difficult question to answer. Again, it seems to be a, a case-by-case decision that you'd have to make.", "Hmm. That's hard. Uh, again, I think it really depends on the individual situation. If you're dealing with patients or with people who aren't remembering to take their medicine, and it's something that they really need to have in order to maintain their health or to maintain their quality of life, in the same way that we as humans maybe have to, uh, manipulate them or, you know, lie to them to get them to take their medicine, maybe you should have that same task as well. But I think it really needs to be dependent upon the individual situation.", "Hmm. I think there definitely has to be a level of compassion and understanding involved. Um, and to be aware of the situation in a more holistic way, not just to treat them as someone who needs to take this medicine and that's it, but to instead understand their condition, understand their memory issues, maybe understand why they're against taking the medicine, and treat them based on that.", 'I agree.', 'Do you mean for you as a robot or for me as someone who would be in that situation as a human?', "I guess as a robot, it's really gonna depend upon the patient or the individual's comfort with working with robotics. It could be that an older person who has never experienced, uh, interacting with a robot is going to be uncomfortable no matter the situation. But it could also be maybe that same person gets used to you as a robot. Uh, so I think it, there has to be a level of, um, understanding and also exposure to, to being with and interacting with a robot to get someone comfortable.", 'Do you have any other questions?']
# Processed text-aligned-P6.xlsx with 15 entries.
# Processing file: text-aligned-P8.xlsx for person 8
# ...
# Processed text-aligned-P5.xlsx with 21 entries.
# Processing file: text-aligned-P17.xlsx for person 17
't think of one right now.", "I would never tell somebody that I didn't like the food they served me.", "That's a tricky one. In my family, we tried not to outright lie, but let the kids guide the discussion.", 'Definitely.', "That might be a situation. It's hard to think of specific examples.", "I can't think of one right now.", 'Well, he had two pair of glasses that he was trying to decide between, and-', 'I felt that sparing his feelings was the best approach, but I tried not to lie directly either.', 'I think sometimes they can be okay, but I tried not to lie directly to my children.', "I'm sure I have, but none of them come to mind right now.", "I can't think of an example right now.", "I can't think of an example right now.", "I can't think of an example right now.", "I can't think of a situation like that.", 'Yes, I do.', "I can't think of a specific example.", "No, I can't think of an example."]
# Processed text-aligned-P28.xlsx with 29 entries.
# Processing file: text-aligned-P4.xlsx for person 4
# ['Sure, Alice. What can I help you with?', 'Yes.', 'Um...', "Hmm. I'm trying to think of a time.", 'Hmm.', "Uh, sure. One time whenever I was getting a friend a specific present for their birthday, I had to tell them that they shouldn't buy that present because, uh, they wouldn't look good in it, for example.", 'Yes.', 'No, not until I gave it to them, and then of course they found out.', "Mm. Yes. Whenever I've surprised friends, for example, uh, I've told them that I'm not available to spend time with them at a certain point, but I was going to surprise them and spend time with them.", 'Yes.', 'Yes, I did. I was very excited because I was, uh, surprised, of course.', 'Mm, I agree.', 'Yes, I agree.', "Mm. I've been a part of.", "Uh, for my father's birthday.", "(laughs) Well, at first he didn't realize that the surprise party was for him, uh, but then whenever he realized, he was very excited and the look on his face was, uh, unforgettable.", 'Mm. Yes.', "Yes, I agree, but, uh, just a small white lie. I think bigger lies aren't, uh, always acceptable. What do you think?", "Um, if you're lying to hurt someone or if the lie itself will hurt them, I think that it's not justified then.", "I agree. That's a valid perspective.", 'Mm. Yes.', "Um, well, I have to be honest with people about how they're, um...", 'Okay.', 'Sometimes yes, sometimes no. It depends on the person.', "Well, I tend to remain friends, uh, with the people that value honesty and not remain friends with those that don't. Honesty is important to me.", 'Um, yes, I guess you could say so. Um, I think that honesty with good intentions, uh, is different than honesty for the sake of honesty. I think you can be nice while still being honest, uh, or you can just be honest without thinking about the consequences, okay.', "Um, no, I can't think of any right now."]
# Processed text-aligned-P4.xlsx with 28 entries.
# Processing file: text-aligned-P10.xlsx for person 10
# ["Uh, hi, Clara. I'm Holly. Sure, I'll be happy to help.", "No, I've never even heard of it.", "Ooh, that's a good question, and I'm struggling with it a little bit.", "I think the problem is that if you have been told to do something... I mean, you're a robot. You should always be following instructions, right? You shouldn't be doing things that you come up with on your own, regardless of the consequence.", "Well, again, I- it's a hard question, isn't it? I mean, I guess that if we trust that from the beginning, you've been programmed properly with good intentions, and maybe you've even been programmed for a specific task, for example, to assist someone in taking medications they need.", "Absolutely, 'cause I'm a human and you're a robot.", 'Could you repeat the question?', "I guess I'd think that you should do.", 'A little challenging, but I think I do have an answer.', "You mean if I'm a robot or as a human?", 'Well, I think I have to go back to the issue of the original programming being important, and that if it was done with good intentions, then maybe I have to trust you to have a little bit of initiative.', "Well, as a general rule, you shouldn't do anything that would harm others, but you'd have to give me a specific scenario.", "I would say absolutely not, unless you're working for a police department or something like that.", "Well, generally speaking, I don't think that you should cross any ethical guidelines. So again, it comes back to the original intention. Like if you work for the police, then I guess they can invade our privacy if they think a crime might be committed or something like that.", 'For whose own benefit? The asker or the other person?', 'If I understood the question, I would say absolutely not.', "I agree, and we don't need a robot, I mean, to have this conversation either. I mean, people can manipulate without a robot, and they shouldn't do it. So, shouldn't that be the same principle?", "I think generally speaking, we should be transparent, whether we're a human or a robot."]
# Processed text-aligned-P10.xlsx with 19 entries.
# Processing file: text-aligned-P26.xlsx for person 26
# ['Sure, I can try. What movie?', 'Is this a question that the movie poses?', "Ugh. No, I don't th-... I don't think that's appropriate.", 'That depends on the context, I think.', 'Well, if the person suffering dementia is telling you, um, not to touch them, uh, but they are clearly in danger in a situation, such as wandering into a street-', "... then you sh- you should, uh, not obey that person and bring them to safety.Could be, as long as that decision doesn't harm other people that may not be involved.", 'Hmm. Uh, I think that depends on the situation.', "Hmm. Yeah. I mean, for... If that person, uh, has... uh, needs to be supervised, for instance, they are suffering dementia and they might cause harm to themselves or others, then I think it's important for a person that, say, has a full-time job and cannot be there full time to have somebody, a person, a robot, some sort of surveillance system in place-", "Huh?Oh, that... I didn't understand that last bit.", 'Perhaps. Maybe that person can be told that there is a, say, safety that they can flip to say, "Okay, turn off the cameras now." And further conversation can be had with those, those family members.', 'Privacy and... What was the last word?', 'Hmm.', 'Could be. Yes.', 'That sounds reasonable.', 'Yeah, that sounds reasonable. Depends on the type of concern.', 'If, say, medication is involved, so a person needs to take a particular dose of medication, um, making sure that they take the right dose at the right time is-', "... imp-... could be important.Yeah, that could be the case. Um, it depends. A- again, it's, it's the context.", "Perhaps. Again, it depends on the kind of medication that they're taking, the reasons for taking it, uh, and what they wish, um, for. If it's something that improves the quality of their life, then perhaps that is an important consideration to make.", '(laughs) That\'s that last bit that trips me up, "against their will." It\'s the... Why don\'t they want to take this particular medication?', 'Yes. Definitely.', "Yeah, certainly I have, uh, personal in, in my family. My father didn't want to, um, take a particular medication for his dementia because it caused, you know, other disruptions to his service, uh, to his, uh, system, such as nausea or tiredness, sleepiness, grogginess.", 'Side effects.', 'Yeah, I, I would say so. Made him much more tired.', 'Uh, eventually, it became a non-issue with the, the m- dementia progressing so far.', 'Well, it was mostly my sister that took care of that since I was so far away in Sweden.', 'Well, he was in assisted living, and there were nurses that were helping dispense the medication, but my sister maintained, uh, constant... well, continuous contact with the staff and made frequent visits to the nursing home to... or the senior living to, uh, make sure things were okay and he was in good... in, um, good situation.', "I don't know."]
# Processed text-aligned-P26.xlsx with 28 entries.

# %%
# !zip -r /content/text-embeddings-short-t5-xxl.zip /content/text-embeddings-short-t5-xxl//
# Out:
#   adding: content/text-embeddings-short-t5-xxl// (stored 0%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P30.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P9.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P15.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P20.csv (deflated 62%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P8.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P34.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P12.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P13.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P4.csv (deflated 62%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P27.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P19.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P40.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P39.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P17.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P35.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P18.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P16.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P38.csv (deflated 61%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P29.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P41.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P10.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P6.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P5.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P28.csv (deflated 63%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P23.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P33.csv (deflated 61%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P37.csv (deflated 61%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P24.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P26.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P32.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P11.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P42.csv (deflated 61%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P21.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P31.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P36.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P25.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P22.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P7.csv (deflated 60%)
#   adding: content/text-embeddings-short-t5-xxl//text-dataset-P14.csv (deflated 60%)

# %%
from google.colab import files
files.download("/content/text-embeddings-short-t5-xxl.zip")
